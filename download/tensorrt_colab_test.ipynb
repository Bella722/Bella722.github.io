# %% [markdown]
# # 首先查看分配的GPU信息

# %%
! nvidia-smi
# Out:
# Sat Oct 10 08:31:12 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 挂载云端硬盘

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # 切换工作目录

# %%
import os

project_path = '/content/gdrive/My Drive/Colab Notebooks/TensorRT Colab Test'  #change dir to your project folder
os.chdir(project_path)

# %% [markdown]
# # 查看cuda版本

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %% [markdown]
# # 查看ubuntu版本

# %%
# !cat /etc/issue
# Out:
# Ubuntu 18.04.5 LTS \n \l

# %% [markdown]
# # 查看tensorflow版本

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# # 卸载当前CUDA版本

# %%
# !sudo apt-get --purge remove cuda nvidia* libnvidia-*
# !sudo dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !sudo apt-get remove cuda-*
# !sudo apt autoremove
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'nvidia-kernel-common-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-325-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-binary' for glob 'nvidia*'
# Note, selecting 'nvidia-331-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-304-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-384-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-340-updates-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-331-updates-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-cg-toolkit' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-390' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-410' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-415' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-418' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-430' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-435' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-440' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-450' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-455' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-340-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-384-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia' for glob 'nvidia*'
# Note, selecting 'nvidia-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-367-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-modprobe' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-texture-tools' for glob 'nvidia*'
# Note, selecting 'nvidia-utils' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-387-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-current-diagnostic' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-340xx-vdpau-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-349-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-304-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-310-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-331-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-352-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-304xx-vdpau-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-vdpau-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-450' for glob 'nvidia*'
# Note, selecting 'nvidia-346-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-331-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-390' for glob 'nvidia*'
# Note, selecting 'nvidia-smi' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-361-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-313-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-340xx-kernel-dkms' for glob 'nvidia*'
# Note, selecting 'nvidia-334-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-410' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-415' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-418' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-430' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-435' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-440' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-450' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-455' for glob 'nvidia*'
# Note, selecting 'nvidia-331-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-prime' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-390' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-dkms' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-410' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-415' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-418' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-430' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-435' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-440' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-450' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-455' for glob 'nvidia*'
# Note, selecting 'nvidia-current-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-340-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager' for glob 'nvidia*'
# Note, selecting 'nvidia-nsight' for glob 'nvidia*'
# Note, selecting 'nvidia-common' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-352-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-390' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-410' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-415' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-418' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-430' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-435' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-440' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-450' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-455' for glob 'nvidia*'
# Note, selecting 'nvidia-current-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-352-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-390' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-410' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-415' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-418' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-430' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-435' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-440' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-450' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-455' for glob 'nvidia*'
# Note, selecting 'nvidia-355-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-libs-nonglvnd' for glob 'nvidia*'
# Note, selecting 'nvidia-375-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-current' for glob 'nvidia*'
# Note, selecting 'nvidia-profiler' for glob 'nvidia*'
# Note, selecting 'nvidia-375-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-390' for glob 'nvidia*'
# Note, selecting 'nvidia-337-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-358-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-367-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-410' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-415' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-418' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-430' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-435' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-440' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-450' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-455' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-toolkit' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-304xx-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-libs' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source' for glob 'nvidia*'
# Note, selecting 'nvidia-378-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-340-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-319-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-450' for glob 'nvidia*'
# Note, selecting 'nvidia-304-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-331-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-visual-profiler' for glob 'nvidia*'
# Note, selecting 'nvidia-persistenced' for glob 'nvidia*'
# Note, selecting 'nvidia-361-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-settings-binary' for glob 'nvidia*'
# Note, selecting 'nvidia-361-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-304' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-331' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-340' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-346' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-352' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-361' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-367' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-375' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-384' for glob 'nvidia*'
# Note, selecting 'nvidia-352-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-331-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-352-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-304-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-340-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-machine-learning-repo-ubuntu1804' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-390' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-340xx-driver' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-304-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-410' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-415' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-418' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-430' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-435' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-440' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-450' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-455' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-doc' for glob 'nvidia*'
# Note, selecting 'nvidia-340-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-361-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-304xx-kernel-dkms' for glob 'nvidia*'
# Note, selecting 'nvidia-cg-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-cg-doc' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-340-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-361-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-381-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-304' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-331' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-340' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-346' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-352' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-361' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-367' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-375' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-gdb' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-304' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-384' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-310' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-313' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-319' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-325' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-331' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-334' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-337' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-340' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-343' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-346' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-349' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-352' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-355' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-358' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-361' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-364' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-367' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-375' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-378' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-381' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-384' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-387' for glob 'nvidia*'
# Note, selecting 'nvidia-343-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-364-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-304' for glob 'nvidia*'
# Note, selecting 'nvidia-310' for glob 'nvidia*'
# Note, selecting 'nvidia-313' for glob 'nvidia*'
# Note, selecting 'nvidia-319' for glob 'nvidia*'
# Note, selecting 'nvidia-325' for glob 'nvidia*'
# Note, selecting 'nvidia-331' for glob 'nvidia*'
# Note, selecting 'nvidia-334' for glob 'nvidia*'
# Note, selecting 'nvidia-337' for glob 'nvidia*'
# Note, selecting 'nvidia-340' for glob 'nvidia*'
# Note, selecting 'nvidia-343' for glob 'nvidia*'
# Note, selecting 'nvidia-346' for glob 'nvidia*'
# Note, selecting 'nvidia-349' for glob 'nvidia*'
# Note, selecting 'nvidia-352' for glob 'nvidia*'
# Note, selecting 'nvidia-355' for glob 'nvidia*'
# Note, selecting 'nvidia-358' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-390' for glob 'nvidia*'
# Note, selecting 'nvidia-361' for glob 'nvidia*'
# Note, selecting 'nvidia-364' for glob 'nvidia*'
# Note, selecting 'nvidia-367' for glob 'nvidia*'
# Note, selecting 'nvidia-375' for glob 'nvidia*'
# Note, selecting 'nvidia-378' for glob 'nvidia*'
# Note, selecting 'nvidia-381' for glob 'nvidia*'
# Note, selecting 'nvidia-384' for glob 'nvidia*'
# Note, selecting 'nvidia-387' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-kernel' for glob 'nvidia*'
# Note, selecting 'nvidia-390' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-410' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-415' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-418' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-346-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-430' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-435' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-440' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-450' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-455' for glob 'nvidia*'
# Note, selecting 'nvidia-settings' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd' for glob 'nvidia*'
# Note, selecting 'nvidia-settings' instead of 'nvidia-settings-binary'
# Package 'nvidia-libopencl1-dev' is not installed, so not removed
# Package 'nvidia-libopencl1' is not installed, so not removed
# Package 'nvidia-vdpau-driver' is not installed, so not removed
# Package 'nvidia-legacy-340xx-vdpau-driver' is not installed, so not removed
# Package 'nvidia-390' is not installed, so not removed
# Package 'nvidia-driver' is not installed, so not removed
# Package 'nvidia-legacy-340xx-driver' is not installed, so not removed
# Package 'nvidia-legacy-304xx-driver' is not installed, so not removed
# Package 'nvidia-kernel-dkms' is not installed, so not removed
# Package 'nvidia-legacy-340xx-kernel-dkms' is not installed, so not removed
# Package 'nvidia-legacy-304xx-kernel-dkms' is not installed, so not removed
# Package 'nvidia' is not installed, so not removed
# Package 'nvidia-current-updates' is not installed, so not removed
# Package 'nvidia-experimental-304' is not installed, so not removed
# Package 'nvidia-310' is not installed, so not removed
# Package 'nvidia-310-updates' is not installed, so not removed
# Package 'nvidia-experimental-310' is not installed, so not removed
# Package 'nvidia-313' is not installed, so not removed
# Package 'nvidia-313-updates' is not installed, so not removed
# Package 'nvidia-experimental-313' is not installed, so not removed
# Package 'nvidia-319' is not installed, so not removed
# Package 'nvidia-319-updates' is not installed, so not removed
# Package 'nvidia-experimental-319' is not installed, so not removed
# Package 'nvidia-325' is not installed, so not removed
# Package 'nvidia-325-updates' is not installed, so not removed
# Package 'nvidia-experimental-325' is not installed, so not removed
# Package 'nvidia-experimental-331' is not installed, so not removed
# Package 'nvidia-334' is not installed, so not removed
# Package 'nvidia-334-updates' is not installed, so not removed
# Package 'nvidia-experimental-334' is not installed, so not removed
# Package 'nvidia-337' is not installed, so not removed
# Package 'nvidia-337-updates' is not installed, so not removed
# Package 'nvidia-experimental-337' is not installed, so not removed
# Package 'nvidia-experimental-340' is not installed, so not removed
# Package 'nvidia-343' is not installed, so not removed
# Package 'nvidia-343-updates' is not installed, so not removed
# Package 'nvidia-experimental-343' is not installed, so not removed
# Package 'nvidia-experimental-346' is not installed, so not removed
# Package 'nvidia-349' is not installed, so not removed
# Package 'nvidia-349-updates' is not installed, so not removed
# Package 'nvidia-experimental-349' is not installed, so not removed
# Package 'nvidia-experimental-352' is not installed, so not removed
# Package 'nvidia-355' is not installed, so not removed
# Package 'nvidia-355-updates' is not installed, so not removed
# Package 'nvidia-experimental-355' is not installed, so not removed
# Package 'nvidia-358' is not installed, so not removed
# Package 'nvidia-358-updates' is not installed, so not removed
# Package 'nvidia-experimental-358' is not installed, so not removed
# Package 'nvidia-experimental-361' is not installed, so not removed
# Package 'nvidia-364' is not installed, so not removed
# Package 'nvidia-364-updates' is not installed, so not removed
# Package 'nvidia-experimental-364' is not installed, so not removed
# Package 'nvidia-367-updates' is not installed, so not removed
# Package 'nvidia-experimental-367' is not installed, so not removed
# Package 'nvidia-375-updates' is not installed, so not removed
# Package 'nvidia-experimental-375' is not installed, so not removed
# Package 'nvidia-378' is not installed, so not removed
# Package 'nvidia-378-updates' is not installed, so not removed
# Package 'nvidia-experimental-378' is not installed, so not removed
# Package 'nvidia-381' is not installed, so not removed
# Package 'nvidia-381-updates' is not installed, so not removed
# Package 'nvidia-experimental-381' is not installed, so not removed
# Package 'nvidia-384-updates' is not installed, so not removed
# Package 'nvidia-experimental-384' is not installed, so not removed
# Package 'nvidia-387' is not installed, so not removed
# Package 'nvidia-387-updates' is not installed, so not removed
# Package 'nvidia-experimental-387' is not installed, so not removed
# Note, selecting 'libnvtt-bin' instead of 'nvidia-texture-tools'
# Package 'nvidia-driver-libs' is not installed, so not removed
# Package 'nvidia-driver-libs-nonglvnd' is not installed, so not removed
# Note, selecting 'nvidia-fabricmanager-450' instead of 'nvidia-fabricmanager'
# Note, selecting 'nvidia-fabricmanager-dev-450' instead of 'nvidia-fabricmanager-dev'
# Package 'nvidia-legacy-304xx-vdpau-driver' is not installed, so not removed
# Note, selecting 'libnvidia-encode-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-415' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ml1' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-415' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-415' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-415' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-415' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-encode-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-415' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-any' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-diagnostic-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-diagnostic-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-diagnostic' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-cfg1-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-415' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-450-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-ifr1' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-390' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-410' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-415' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-418' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-430' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-435' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-common-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-compute-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-fbc1-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-440' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-450' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-extra-455' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-gl-440-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-decode-418-server' for glob 'libnvidia-*'
# Note, selecting 'libnvidia-nscq-450' instead of 'libnvidia-nscq'
# Package 'nvidia-340-updates-uvm' is not installed, so not removed
# Package 'nvidia-346' is not installed, so not removed
# Package 'nvidia-346-dev' is not installed, so not removed
# Package 'nvidia-346-updates' is not installed, so not removed
# Package 'nvidia-346-updates-dev' is not installed, so not removed
# Package 'nvidia-352' is not installed, so not removed
# Package 'nvidia-352-dev' is not installed, so not removed
# Package 'nvidia-352-updates' is not installed, so not removed
# Package 'nvidia-352-updates-dev' is not installed, so not removed
# Package 'nvidia-361' is not installed, so not removed
# Package 'nvidia-361-dev' is not installed, so not removed
# Package 'nvidia-361-updates' is not installed, so not removed
# Package 'nvidia-361-updates-dev' is not installed, so not removed
# Package 'nvidia-367' is not installed, so not removed
# Package 'nvidia-367-dev' is not installed, so not removed
# Package 'nvidia-375' is not installed, so not removed
# Package 'nvidia-375-dev' is not installed, so not removed
# Package 'nvidia-cg-dev' is not installed, so not removed
# Package 'nvidia-cg-doc' is not installed, so not removed
# Package 'nvidia-cg-toolkit' is not installed, so not removed
# Package 'nvidia-cuda-dev' is not installed, so not removed
# Package 'nvidia-cuda-doc' is not installed, so not removed
# Package 'nvidia-cuda-gdb' is not installed, so not removed
# Package 'nvidia-cuda-toolkit' is not installed, so not removed
# Package 'nvidia-libopencl1-346' is not installed, so not removed
# Package 'nvidia-libopencl1-346-updates' is not installed, so not removed
# Package 'nvidia-libopencl1-352' is not installed, so not removed
# Package 'nvidia-libopencl1-352-updates' is not installed, so not removed
# Package 'nvidia-libopencl1-361' is not installed, so not removed
# Package 'nvidia-libopencl1-361-updates' is not installed, so not removed
# Package 'nvidia-libopencl1-367' is not installed, so not removed
# Package 'nvidia-libopencl1-375' is not installed, so not removed
# Package 'nvidia-nsight' is not installed, so not removed
# Package 'nvidia-opencl-icd-346' is not installed, so not removed
# Package 'nvidia-opencl-icd-346-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-352' is not installed, so not removed
# Package 'nvidia-opencl-icd-352-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-361' is not installed, so not removed
# Package 'nvidia-opencl-icd-361-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-367' is not installed, so not removed
# Package 'nvidia-opencl-icd-375' is not installed, so not removed
# Package 'nvidia-profiler' is not installed, so not removed
# Package 'nvidia-visual-profiler' is not installed, so not removed
# Package 'nvidia-prime' is not installed, so not removed
# Package 'libnvidia-cfg1-390' is not installed, so not removed
# Package 'libnvidia-cfg1-435' is not installed, so not removed
# Package 'libnvidia-cfg1-440' is not installed, so not removed
# Package 'libnvidia-common-390' is not installed, so not removed
# Package 'libnvidia-common-435' is not installed, so not removed
# Package 'libnvidia-common-440' is not installed, so not removed
# Package 'libnvidia-compute-390' is not installed, so not removed
# Package 'libnvidia-compute-435' is not installed, so not removed
# Package 'libnvidia-compute-440' is not installed, so not removed
# Package 'libnvidia-decode-390' is not installed, so not removed
# Package 'libnvidia-decode-435' is not installed, so not removed
# Package 'libnvidia-decode-440' is not installed, so not removed
# Package 'libnvidia-encode-390' is not installed, so not removed
# Package 'libnvidia-encode-435' is not installed, so not removed
# Package 'libnvidia-encode-440' is not installed, so not removed
# Package 'libnvidia-extra-440' is not installed, so not removed
# Package 'libnvidia-fbc1-390' is not installed, so not removed
# Package 'libnvidia-fbc1-435' is not installed, so not removed
# Package 'libnvidia-fbc1-440' is not installed, so not removed
# Package 'libnvidia-gl-390' is not installed, so not removed
# Package 'libnvidia-gl-435' is not installed, so not removed
# Package 'libnvidia-gl-440' is not installed, so not removed
# Package 'libnvidia-ifr1-390' is not installed, so not removed
# Package 'libnvidia-ifr1-435' is not installed, so not removed
# Package 'libnvidia-ifr1-440' is not installed, so not removed
# Package 'nvidia-331' is not installed, so not removed
# Package 'nvidia-331-dev' is not installed, so not removed
# Package 'nvidia-331-updates' is not installed, so not removed
# Package 'nvidia-331-updates-dev' is not installed, so not removed
# Package 'nvidia-331-updates-uvm' is not installed, so not removed
# Package 'nvidia-331-uvm' is not installed, so not removed
# Package 'nvidia-340' is not installed, so not removed
# Package 'nvidia-340-dev' is not installed, so not removed
# Package 'nvidia-340-updates' is not installed, so not removed
# Package 'nvidia-340-updates-dev' is not installed, so not removed
# Package 'nvidia-340-uvm' is not installed, so not removed
# Package 'nvidia-compute-utils-390' is not installed, so not removed
# Package 'nvidia-compute-utils-435' is not installed, so not removed
# Package 'nvidia-compute-utils-440' is not installed, so not removed
# Package 'nvidia-dkms-390' is not installed, so not removed
# Package 'nvidia-dkms-435' is not installed, so not removed
# Package 'nvidia-dkms-440' is not installed, so not removed
# Package 'nvidia-driver-390' is not installed, so not removed
# Package 'nvidia-driver-435' is not installed, so not removed
# Package 'nvidia-driver-440' is not installed, so not removed
# Package 'nvidia-headless-390' is not installed, so not removed
# Package 'nvidia-headless-435' is not installed, so not removed
# Package 'nvidia-headless-440' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-390' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-435' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-440' is not installed, so not removed
# Package 'nvidia-kernel-common-390' is not installed, so not removed
# Package 'nvidia-kernel-common-435' is not installed, so not removed
# Package 'nvidia-kernel-common-440' is not installed, so not removed
# Package 'nvidia-kernel-source-390' is not installed, so not removed
# Package 'nvidia-kernel-source-435' is not installed, so not removed
# Package 'nvidia-kernel-source-440' is not installed, so not removed
# Package 'nvidia-opencl-icd-340' is not installed, so not removed
# Package 'nvidia-utils-390' is not installed, so not removed
# Package 'nvidia-utils-435' is not installed, so not removed
# Package 'nvidia-utils-440' is not installed, so not removed
# Package 'nvidia-common' is not installed, so not removed
# Package 'libnvidia-cfg1-418-server' is not installed, so not removed
# Package 'libnvidia-cfg1-440-server' is not installed, so not removed
# Package 'libnvidia-cfg1-450-server' is not installed, so not removed
# Package 'libnvidia-common-418-server' is not installed, so not removed
# Package 'libnvidia-common-440-server' is not installed, so not removed
# Package 'libnvidia-common-450-server' is not installed, so not removed
# Package 'libnvidia-compute-418-server' is not installed, so not removed
# Package 'libnvidia-compute-440-server' is not installed, so not removed
# Package 'libnvidia-compute-450-server' is not installed, so not removed
# Package 'libnvidia-decode-418-server' is not installed, so not removed
# Package 'libnvidia-decode-440-server' is not installed, so not removed
# Package 'libnvidia-decode-450-server' is not installed, so not removed
# Package 'libnvidia-encode-418-server' is not installed, so not removed
# Package 'libnvidia-encode-440-server' is not installed, so not removed
# Package 'libnvidia-encode-450-server' is not installed, so not removed
# Package 'libnvidia-extra-440-server' is not installed, so not removed
# Package 'libnvidia-extra-450-server' is not installed, so not removed
# Package 'libnvidia-fbc1-418-server' is not installed, so not removed
# Package 'libnvidia-fbc1-440-server' is not installed, so not removed
# Package 'libnvidia-fbc1-450-server' is not installed, so not removed
# Package 'libnvidia-gl-418-server' is not installed, so not removed
# Package 'libnvidia-gl-440-server' is not installed, so not removed
# Package 'libnvidia-gl-450-server' is not installed, so not removed
# Package 'libnvidia-ifr1-418-server' is not installed, so not removed
# Package 'libnvidia-ifr1-440-server' is not installed, so not removed
# Package 'libnvidia-ifr1-450-server' is not installed, so not removed
# Package 'nvidia-compute-utils-418-server' is not installed, so not removed
# Package 'nvidia-compute-utils-440-server' is not installed, so not removed
# Package 'nvidia-compute-utils-450-server' is not installed, so not removed
# Package 'nvidia-dkms-418-server' is not installed, so not removed
# Package 'nvidia-dkms-440-server' is not installed, so not removed
# Package 'nvidia-dkms-450-server' is not installed, so not removed
# Package 'nvidia-driver-418-server' is not installed, so not removed
# Package 'nvidia-driver-440-server' is not installed, so not removed
# Package 'nvidia-driver-450-server' is not installed, so not removed
# Package 'nvidia-headless-418-server' is not installed, so not removed
# Package 'nvidia-headless-440-server' is not installed, so not removed
# Package 'nvidia-headless-450-server' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-418-server' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-440-server' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-450-server' is not installed, so not removed
# Package 'nvidia-kernel-common-418-server' is not installed, so not removed
# Package 'nvidia-kernel-common-440-server' is not installed, so not removed
# Package 'nvidia-kernel-common-450-server' is not installed, so not removed
# Package 'nvidia-kernel-source-418-server' is not installed, so not removed
# Package 'nvidia-kernel-source-440-server' is not installed, so not removed
# Package 'nvidia-kernel-source-450-server' is not installed, so not removed
# Package 'nvidia-libopencl1-331' is not installed, so not removed
# Package 'nvidia-libopencl1-331-updates' is not installed, so not removed
# Package 'nvidia-libopencl1-340' is not installed, so not removed
# Package 'nvidia-libopencl1-340-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-331' is not installed, so not removed
# Package 'nvidia-opencl-icd-331-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-340-updates' is not installed, so not removed
# Package 'nvidia-utils-418-server' is not installed, so not removed
# Package 'nvidia-utils-440-server' is not installed, so not removed
# Package 'nvidia-utils-450-server' is not installed, so not removed
# Package 'libnvidia-cfg1-410' is not installed, so not removed
# Package 'libnvidia-common-410' is not installed, so not removed
# Package 'libnvidia-compute-410' is not installed, so not removed
# Package 'libnvidia-decode-410' is not installed, so not removed
# Package 'libnvidia-diagnostic-410' is not installed, so not removed
# Package 'libnvidia-diagnostic-418' is not installed, so not removed
# Package 'libnvidia-encode-410' is not installed, so not removed
# Package 'libnvidia-fbc1-410' is not installed, so not removed
# Package 'libnvidia-gl-410' is not installed, so not removed
# Package 'libnvidia-ifr1-410' is not installed, so not removed
# Package 'nvidia-compute-utils-410' is not installed, so not removed
# Package 'nvidia-dkms-410' is not installed, so not removed
# Package 'nvidia-driver-410' is not installed, so not removed
# Package 'nvidia-headless-410' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-410' is not installed, so not removed
# Package 'nvidia-kernel-common-410' is not installed, so not removed
# Package 'nvidia-kernel-source-410' is not installed, so not removed
# Package 'nvidia-utils-410' is not installed, so not removed
# Package 'cuda' is not installed, so not removed
# Package 'libnvidia-common-430' is not installed, so not removed
# Package 'libnvidia-decode-430' is not installed, so not removed
# Package 'libnvidia-encode-430' is not installed, so not removed
# Package 'libnvidia-fbc1-430' is not installed, so not removed
# Package 'libnvidia-ifr1-430' is not installed, so not removed
# Package 'nvidia-compute-utils-430' is not installed, so not removed
# Package 'nvidia-dkms-430' is not installed, so not removed
# Package 'nvidia-driver-430' is not installed, so not removed
# Package 'nvidia-headless-430' is not installed, so not removed
# Package 'nvidia-headless-455' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-430' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-455' is not installed, so not removed
# Package 'nvidia-kernel-common-430' is not installed, so not removed
# Package 'nvidia-kernel-source-430' is not installed, so not removed
# Package 'nvidia-utils-430' is not installed, so not removed
# Package 'libnvidia-cfg1-450' is not installed, so not removed
# Package 'libnvidia-common-450' is not installed, so not removed
# Package 'libnvidia-compute-450' is not installed, so not removed
# Package 'libnvidia-decode-450' is not installed, so not removed
# Package 'libnvidia-encode-450' is not installed, so not removed
# Package 'libnvidia-extra-450' is not installed, so not removed
# Package 'libnvidia-fbc1-450' is not installed, so not removed
# Package 'libnvidia-gl-450' is not installed, so not removed
# Package 'libnvidia-ifr1-450' is not installed, so not removed
# Package 'libnvidia-nscq-450' is not installed, so not removed
# Package 'nvidia-384' is not installed, so not removed
# Package 'nvidia-384-dev' is not installed, so not removed
# Package 'nvidia-compute-utils-450' is not installed, so not removed
# Package 'nvidia-dkms-450' is not installed, so not removed
# Package 'nvidia-driver-450' is not installed, so not removed
# Package 'nvidia-fabricmanager-450' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-450' is not installed, so not removed
# Package 'nvidia-headless-450' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-450' is not installed, so not removed
# Package 'nvidia-kernel-common-450' is not installed, so not removed
# Package 'nvidia-kernel-source-450' is not installed, so not removed
# Package 'nvidia-libopencl1-384' is not installed, so not removed
# Package 'nvidia-opencl-icd-384' is not installed, so not removed
# Package 'nvidia-utils-450' is not installed, so not removed
# Package 'libnvidia-cfg1-415' is not installed, so not removed
# Package 'libnvidia-common-415' is not installed, so not removed
# Package 'libnvidia-common-418' is not installed, so not removed
# Package 'libnvidia-compute-415' is not installed, so not removed
# Package 'libnvidia-decode-415' is not installed, so not removed
# Package 'libnvidia-decode-418' is not installed, so not removed
# Package 'libnvidia-encode-415' is not installed, so not removed
# Package 'libnvidia-encode-418' is not installed, so not removed
# Package 'libnvidia-fbc1-415' is not installed, so not removed
# Package 'libnvidia-fbc1-418' is not installed, so not removed
# Package 'libnvidia-gl-415' is not installed, so not removed
# Package 'libnvidia-ifr1-415' is not installed, so not removed
# Package 'libnvidia-ifr1-418' is not installed, so not removed
# Package 'nvidia-304' is not installed, so not removed
# Package 'nvidia-304-dev' is not installed, so not removed
# Package 'nvidia-304-updates' is not installed, so not removed
# Package 'nvidia-304-updates-dev' is not installed, so not removed
# Package 'nvidia-compute-utils-415' is not installed, so not removed
# Package 'nvidia-compute-utils-418' is not installed, so not removed
# Package 'nvidia-current' is not installed, so not removed
# Package 'nvidia-current-dev' is not installed, so not removed
# Package 'nvidia-dkms-415' is not installed, so not removed
# Package 'nvidia-dkms-418' is not installed, so not removed
# Package 'nvidia-driver-415' is not installed, so not removed
# Package 'nvidia-driver-418' is not installed, so not removed
# Package 'nvidia-headless-415' is not installed, so not removed
# Package 'nvidia-headless-418' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-415' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-418' is not installed, so not removed
# Package 'nvidia-kernel-common-415' is not installed, so not removed
# Package 'nvidia-kernel-common-418' is not installed, so not removed
# Package 'nvidia-kernel-source-415' is not installed, so not removed
# Package 'nvidia-kernel-source-418' is not installed, so not removed
# Package 'nvidia-libopencl1-304' is not installed, so not removed
# Package 'nvidia-libopencl1-304-updates' is not installed, so not removed
# Package 'nvidia-opencl-icd-304' is not installed, so not removed
# Package 'nvidia-opencl-icd-304-updates' is not installed, so not removed
# Package 'nvidia-utils-415' is not installed, so not removed
# Package 'nvidia-utils-418' is not installed, so not removed
# Package 'nvidia-machine-learning-repo-ubuntu1804' is not installed, so not removed
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-compiler-10-0 cuda-cuobjdump-10-0
#   cuda-cupti-10-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-gdb-10-0 cuda-gpu-library-advisor-10-0 cuda-libraries-10-0
#   cuda-memcheck-10-0 cuda-nsight-10-0 cuda-nsight-10-1
#   cuda-nsight-compute-10-0 cuda-nsight-compute-10-1 cuda-nsight-systems-10-1
#   cuda-nvcc-10-0 cuda-nvdisasm-10-0 cuda-nvml-dev-10-0 cuda-nvprof-10-0
#   cuda-nvprune-10-0 cuda-nvtx-10-0 cuda-nvvp-10-0 cuda-nvvp-10-1
#   cuda-samples-10-0 cuda-samples-10-1 cuda-toolkit-10-0 cuda-toolkit-10-1
#   cuda-tools-10-0 cuda-tools-10-1 cuda-visual-tools-10-0
#   cuda-visual-tools-10-1 default-jre dkms freeglut3 freeglut3-dev
#   keyboard-configuration libargon2-0 libcap2 libcryptsetup12
#   libdevmapper1.02.1 libfontenc1 libidn11 libip4tc0 libjansson4 libpam-systemd
#   libpolkit-agent-1-0 libpolkit-backend-1-0 libpolkit-gobject-1-0 libxfont2
#   libxi-dev libxkbfile1 libxmu-dev libxmu-headers libxnvctrl0
#   nsight-compute-2020.2.0 nsight-systems-2020.3.4 ocl-icd-opencl-dev
#   opencl-c-headers openjdk-11-jre policykit-1 policykit-1-gnome python3-xkit
#   screen-resolution-extra systemd systemd-sysv udev x11-xkb-utils
#   xserver-common xserver-xorg-core-hwe-18.04
# Use 'sudo apt autoremove' to remove them.
# The following packages will be REMOVED:
#   cuda-10-0* cuda-10-1* cuda-demo-suite-10-0* cuda-demo-suite-10-1*
#   cuda-drivers* cuda-drivers-455* cuda-runtime-10-0* cuda-runtime-10-1*
#   libnvidia-cfg1-418* libnvidia-cfg1-430* libnvidia-cfg1-455*
#   libnvidia-common-455* libnvidia-compute-418* libnvidia-compute-430*
#   libnvidia-compute-455* libnvidia-decode-455* libnvidia-encode-455*
#   libnvidia-extra-455* libnvidia-fbc1-455* libnvidia-gl-418* libnvidia-gl-430*
#   libnvidia-gl-455* libnvidia-ifr1-455* nvidia-compute-utils-455*
#   nvidia-dkms-455* nvidia-driver-455* nvidia-kernel-common-455*
#   nvidia-kernel-source-455* nvidia-modprobe* nvidia-opencl-dev*
#   nvidia-settings* nvidia-utils-455* xserver-xorg-video-nvidia-455*
# 0 upgraded, 0 newly installed, 33 to remove and 6 not upgraded.
# After this operation, 469 MB disk space will be freed.
# (Reading database ... 144617 files and directories currently installed.)
# Removing cuda-10-0 (10.0.130-1) ...
# Removing cuda-10-1 (10.1.243-1) ...
# Removing cuda-demo-suite-10-0 (10.0.130-1) ...
# Removing cuda-demo-suite-10-1 (10.1.243-1) ...
# Removing cuda-runtime-10-1 (10.1.243-1) ...
# Removing cuda-runtime-10-0 (10.0.130-1) ...
# Removing cuda-drivers (455.23.05-1) ...
# Removing cuda-drivers-455 (455.23.05-1) ...
# Removing libnvidia-cfg1-418:amd64 (430.64-0ubuntu0~gpu18.04.1) ...
# Removing libnvidia-cfg1-430:amd64 (455.23.05-0ubuntu1) ...
# Removing nvidia-driver-455 (455.23.05-0ubuntu1) ...
# Removing xserver-xorg-video-nvidia-455 (455.23.05-0ubuntu1) ...
# Removing libnvidia-cfg1-455:amd64 (455.23.05-0ubuntu1) ...
# Removing libnvidia-ifr1-455:amd64 (455.23.05-0ubuntu1) ...
# Removing libnvidia-gl-418:amd64 (430.64-0ubuntu0~gpu18.04.1) ...
# Removing libnvidia-gl-430:amd64 (455.23.05-0ubuntu1) ...
# Removing libnvidia-gl-455:amd64 (455.23.05-0ubuntu1) ...
# Removing libnvidia-common-455 (455.23.05-0ubuntu1) ...
# Removing libnvidia-compute-418:amd64 (430.64-0ubuntu0~gpu18.04.1) ...
# Removing libnvidia-compute-430:amd64 (455.23.05-0ubuntu1) ...
# Removing libnvidia-encode-455:amd64 (455.23.05-0ubuntu1) ...
# Removing libnvidia-decode-455:amd64 (455.23.05-0ubuntu1) ...
# Removing nvidia-utils-455 (455.23.05-0ubuntu1) ...
# Removing libnvidia-extra-455:amd64 (455.23.05-0ubuntu1) ...
# Removing libnvidia-fbc1-455:amd64 (455.23.05-0ubuntu1) ...
# Removing nvidia-compute-utils-455 (455.23.05-0ubuntu1) ...
# ...
# Package 'cuda-compat-10-0' is not installed, so not removed
# Package 'cuda-compiler-10-2' is not installed, so not removed
# Package 'cuda-core-10-0' is not installed, so not removed
# Package 'cuda-core-10-1' is not installed, so not removed
# Package 'cuda-core-10-2' is not installed, so not removed
# Package 'cuda-cross-qnx-10-0' is not installed, so not removed
# Package 'cuda-cross-qnx' is not installed, so not removed
# Package 'cuda-cudart-10-2' is not installed, so not removed
# Package 'cuda-cudart-dev-10-2' is not installed, so not removed
# Package 'cuda-cufft-10-2' is not installed, so not removed
# Package 'cuda-cufft-dev-10-2' is not installed, so not removed
# Package 'cuda-cuobjdump-10-2' is not installed, so not removed
# Package 'cuda-cupti-10-2' is not installed, so not removed
# Package 'cuda-cupti-dev-10-2' is not installed, so not removed
# Package 'cuda-curand-10-2' is not installed, so not removed
# Package 'cuda-curand-dev-10-2' is not installed, so not removed
# Package 'cuda-cusolver-10-2' is not installed, so not removed
# Package 'cuda-cusolver-dev-10-2' is not installed, so not removed
# Package 'cuda-cusparse-10-2' is not installed, so not removed
# Package 'cuda-cusparse-dev-10-2' is not installed, so not removed
# Package 'cuda-demo-suite-10-0' is not installed, so not removed
# Package 'cuda-demo-suite-10-1' is not installed, so not removed
# Package 'cuda-demo-suite-10-2' is not installed, so not removed
# Package 'cuda-demo-suite-11-0' is not installed, so not removed
# Package 'cuda-documentation-10-2' is not installed, so not removed
# Package 'cuda-driver-dev-10-2' is not installed, so not removed
# Package 'cuda-drivers-diagnostic' is not installed, so not removed
# Package 'cuda-gdb-10-2' is not installed, so not removed
# Package 'cuda-gdb-src-10-0' is not installed, so not removed
# Package 'cuda-gdb-src-10-1' is not installed, so not removed
# Package 'cuda-gdb-src-10-2' is not installed, so not removed
# Package 'cuda-libraries-10-0' is not installed, so not removed
# Package 'cuda-libraries-10-1' is not installed, so not removed
# Package 'cuda-libraries-10-2' is not installed, so not removed
# Package 'cuda-libraries-dev-10-2' is not installed, so not removed
# Package 'cuda-license-10-2' is not installed, so not removed
# Package 'cuda-memcheck-10-2' is not installed, so not removed
# Package 'cuda-minimal-build-10-0' is not installed, so not removed
# Package 'cuda-minimal-build-10-1' is not installed, so not removed
# Package 'cuda-minimal-build-10-2' is not installed, so not removed
# Package 'cuda-misc-headers-10-2' is not installed, so not removed
# Package 'cuda-npp-10-2' is not installed, so not removed
# Package 'cuda-npp-dev-10-2' is not installed, so not removed
# Package 'cuda-nsight-10-2' is not installed, so not removed
# Package 'cuda-nsight-compute--10-0' is not installed, so not removed
# Package 'cuda-nsight-compute-10-2' is not installed, so not removed
# Package 'cuda-nsight-systems-10-2' is not installed, so not removed
# Package 'cuda-nvcc-10-2' is not installed, so not removed
# Package 'cuda-nvdisasm-10-2' is not installed, so not removed
# Package 'cuda-nvgraph-10-2' is not installed, so not removed
# Package 'cuda-nvgraph-dev-10-2' is not installed, so not removed
# Package 'cuda-nvjpeg-10-2' is not installed, so not removed
# Package 'cuda-nvjpeg-dev-10-2' is not installed, so not removed
# Package 'cuda-nvml-dev-10-2' is not installed, so not removed
# Package 'cuda-nvml-dev-11-0' is not installed, so not removed
# Package 'cuda-nvprof-10-2' is not installed, so not removed
# Package 'cuda-nvprune-10-2' is not installed, so not removed
# Package 'cuda-nvrtc-10-2' is not installed, so not removed
# Package 'cuda-nvrtc-dev-10-2' is not installed, so not removed
# Package 'cuda-nvtx-10-2' is not installed, so not removed
# Package 'cuda-nvtx-11-0' is not installed, so not removed
# Package 'cuda-nvvp-10-2' is not installed, so not removed
# Package 'cuda-repo-ubuntu1804' is not installed, so not removed
# Package 'cuda-runtime-10-0' is not installed, so not removed
# Package 'cuda-runtime-10-1' is not installed, so not removed
# Package 'cuda-runtime-10-2' is not installed, so not removed
# Package 'cuda-samples-10-2' is not installed, so not removed
# Package 'cuda-sanitizer-api-10-2' is not installed, so not removed
# Package 'cuda-toolkit-10-0' is not installed, so not removed
# Package 'cuda-toolkit-10-1' is not installed, so not removed
# Package 'cuda-toolkit-10-2' is not installed, so not removed
# Package 'cuda-tools-10-0' is not installed, so not removed
# Package 'cuda-tools-10-1' is not installed, so not removed
# Package 'cuda-tools-10-2' is not installed, so not removed
# Package 'cuda-visual-tools-10-0' is not installed, so not removed
# Package 'cuda-visual-tools-10-1' is not installed, so not removed
# Package 'cuda-visual-tools-10-2' is not installed, so not removed
# Package 'cuda-11-0' is not installed, so not removed
# Package 'cuda-command-line-tools-11-0' is not installed, so not removed
# Package 'cuda-compiler-11-0' is not installed, so not removed
# Package 'cuda-cudart-11-0' is not installed, so not removed
# Package 'cuda-cudart-dev-11-0' is not installed, so not removed
# Package 'cuda-cuobjdump-11-0' is not installed, so not removed
# Package 'cuda-cupti-11-0' is not installed, so not removed
# Package 'cuda-cupti-dev-11-0' is not installed, so not removed
# Package 'cuda-documentation-11-0' is not installed, so not removed
# Package 'cuda-driver-dev-11-0' is not installed, so not removed
# Package 'cuda-gdb-11-0' is not installed, so not removed
# Package 'cuda-gdb-src-11-0' is not installed, so not removed
# Package 'cuda-libraries-11-0' is not installed, so not removed
# Package 'cuda-libraries-dev-11-0' is not installed, so not removed
# Package 'cuda-memcheck-11-0' is not installed, so not removed
# Package 'cuda-minimal-build-11-0' is not installed, so not removed
# Package 'cuda-nsight-11-0' is not installed, so not removed
# Package 'cuda-nsight-compute-11-0' is not installed, so not removed
# Package 'cuda-nsight-systems-11-0' is not installed, so not removed
# Package 'cuda-nvcc-11-0' is not installed, so not removed
# Package 'cuda-nvdisasm-11-0' is not installed, so not removed
# Package 'cuda-nvprof-11-0' is not installed, so not removed
# Package 'cuda-nvprune-11-0' is not installed, so not removed
# Package 'cuda-nvrtc-11-0' is not installed, so not removed
# Package 'cuda-nvrtc-dev-11-0' is not installed, so not removed
# Package 'cuda-nvvp-11-0' is not installed, so not removed
# Package 'cuda-runtime-11-0' is not installed, so not removed
# Package 'cuda-samples-11-0' is not installed, so not removed
# Package 'cuda-sanitizer-11-0' is not installed, so not removed
# Package 'cuda-toolkit-11-0' is not installed, so not removed
# Package 'cuda-tools-11-0' is not installed, so not removed
# Package 'cuda-visual-tools-11-0' is not installed, so not removed
# Package 'cuda-11-1' is not installed, so not removed
# Package 'cuda-command-line-tools-11-1' is not installed, so not removed
# Package 'cuda-compat-11-1' is not installed, so not removed
# Package 'cuda-compiler-11-1' is not installed, so not removed
# Package 'cuda-cudart-11-1' is not installed, so not removed
# Package 'cuda-cudart-dev-11-1' is not installed, so not removed
# Package 'cuda-cuobjdump-11-1' is not installed, so not removed
# Package 'cuda-cupti-11-1' is not installed, so not removed
# Package 'cuda-cupti-dev-11-1' is not installed, so not removed
# Package 'cuda-demo-suite-11-1' is not installed, so not removed
# Package 'cuda-documentation-11-1' is not installed, so not removed
# Package 'cuda-driver-dev-11-1' is not installed, so not removed
# Package 'cuda-drivers' is not installed, so not removed
# Package 'cuda-drivers-455' is not installed, so not removed
# Package 'cuda-gdb-11-1' is not installed, so not removed
# Package 'cuda-gdb-src-11-1' is not installed, so not removed
# Package 'cuda-libraries-11-1' is not installed, so not removed
# Package 'cuda-libraries-dev-11-1' is not installed, so not removed
# Package 'cuda-memcheck-11-1' is not installed, so not removed
# Package 'cuda-minimal-build-11-1' is not installed, so not removed
# Package 'cuda-nsight-11-1' is not installed, so not removed
# Package 'cuda-nsight-compute-11-1' is not installed, so not removed
# Package 'cuda-nsight-systems-11-1' is not installed, so not removed
# Package 'cuda-nvcc-11-1' is not installed, so not removed
# Package 'cuda-nvdisasm-11-1' is not installed, so not removed
# Package 'cuda-nvml-dev-11-1' is not installed, so not removed
# Package 'cuda-nvprof-11-1' is not installed, so not removed
# Package 'cuda-nvprune-11-1' is not installed, so not removed
# Package 'cuda-nvrtc-11-1' is not installed, so not removed
# Package 'cuda-nvrtc-dev-11-1' is not installed, so not removed
# Package 'cuda-nvtx-11-1' is not installed, so not removed
# Package 'cuda-nvvp-11-1' is not installed, so not removed
# Package 'cuda-runtime-11-1' is not installed, so not removed
# Package 'cuda-samples-11-1' is not installed, so not removed
# Package 'cuda-sanitizer-11-1' is not installed, so not removed
# Package 'cuda-toolkit-11-1' is not installed, so not removed
# Package 'cuda-tools-11-1' is not installed, so not removed
# Package 'cuda-visual-tools-11-1' is not installed, so not removed
# Package 'cuda-compat-10-2' is not installed, so not removed
# Package 'cuda-drivers-440' is not installed, so not removed
# Package 'cuda-compat-10-1' is not installed, so not removed
# Package 'cuda-compat-11-0' is not installed, so not removed
# Package 'cuda-drivers-418' is not installed, so not removed
# Package 'cuda-drivers-450' is not installed, so not removed
# Package 'cuda-drivers-fabricmanager-450' is not installed, so not removed
# Package 'cuda-drivers-fabricmanager' is not installed, so not removed
# Some packages could not be installed. This may mean that you have
# requested an impossible situation or if you are using the unstable
# distribution that some required packages have not yet been created
# or been moved out of Incoming.
# The following information may help to resolve the situation:
#
# The following packages have unmet dependencies:
#  libcublas-dev : Depends: cuda-license-10-1 but it is not going to be installed
#  libcublas10 : Depends: cuda-license-10-1 but it is not going to be installed
# E: Error, pkgProblemResolver::Resolve generated breaks, this may be caused by held packages.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages will be REMOVED:
#   cuda-command-line-tools-10-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-cuobjdump-10-0 cuda-cupti-10-0 cuda-documentation-10-0
#   cuda-documentation-10-1 cuda-gdb-10-0 cuda-gpu-library-advisor-10-0
#   cuda-memcheck-10-0 cuda-nsight-10-0 cuda-nsight-10-1
#   cuda-nsight-compute-10-0 cuda-nsight-compute-10-1 cuda-nsight-systems-10-1
#   cuda-nvcc-10-0 cuda-nvdisasm-10-0 cuda-nvml-dev-10-0 cuda-nvprof-10-0
#   cuda-nvprune-10-0 cuda-nvprune-10-1 cuda-nvtx-10-0 cuda-nvvp-10-0
#   cuda-nvvp-10-1 cuda-samples-10-0 cuda-samples-10-1 default-jre dkms
#   freeglut3 freeglut3-dev keyboard-configuration libargon2-0 libcap2
#   libcryptsetup12 libdevmapper1.02.1 libfontenc1 libidn11 libip4tc0
#   libjansson4 libpam-systemd libpolkit-agent-1-0 libpolkit-backend-1-0
#   libpolkit-gobject-1-0 libxfont2 libxi-dev libxkbfile1 libxmu-dev
#   libxmu-headers libxnvctrl0 nsight-compute-2020.2.0 nsight-systems-2020.3.4
#   ocl-icd-opencl-dev opencl-c-headers openjdk-11-jre policykit-1
#   policykit-1-gnome python3-xkit screen-resolution-extra systemd systemd-sysv
#   udev x11-xkb-utils xserver-common xserver-xorg-core-hwe-18.04
# 0 upgraded, 0 newly installed, 64 to remove and 6 not upgraded.
# After this operation, 2,301 MB disk space will be freed.
# (Reading database ... 138227 files and directories currently installed.)
# Removing cuda-command-line-tools-10-0 (10.0.130-1) ...
# Removing cuda-compiler-10-0 (10.0.130-1) ...
# Removing cuda-compiler-10-1 (10.1.243-1) ...
# Removing cuda-gdb-10-0 (10.0.130-1) ...
# Removing cuda-cuobjdump-10-0 (10.0.130-1) ...
# Removing cuda-cupti-10-0 (10.0.130-1) ...
# Removing cuda-documentation-10-0 (10.0.130-1) ...
# Removing cuda-documentation-10-1 (10.1.243-1) ...
# Removing cuda-gpu-library-advisor-10-0 (10.0.130-1) ...
# Removing cuda-memcheck-10-0 (10.0.130-1) ...
# Removing cuda-nsight-10-0 (10.0.130-1) ...
# Removing cuda-nsight-10-1 (10.1.243-1) ...
# Removing cuda-nsight-compute-10-0 (10.0.130-1) ...
# Removing cuda-nsight-compute-10-1 (10.1.243-1) ...
# Removing cuda-nsight-systems-10-1 (10.1.243-1) ...
# Removing cuda-samples-10-0 (10.0.130-1) ...
# Removing cuda-nvcc-10-0 (10.0.130-1) ...
# Removing cuda-nvdisasm-10-0 (10.0.130-1) ...
# Removing cuda-nvml-dev-10-0 (10.0.130-1) ...
# Removing cuda-nvprof-10-0 (10.0.130-1) ...
# Removing cuda-nvprune-10-0 (10.0.130-1) ...
# Removing cuda-nvprune-10-1 (10.1.243-1) ...
# Removing cuda-nvtx-10-0 (10.0.130-1) ...
# Removing cuda-nvvp-10-0 (10.0.130-1) ...
# Removing cuda-nvvp-10-1 (10.1.243-1) ...
# Removing cuda-samples-10-1 (10.1.243-1) ...
# Removing default-jre (2:1.11-68ubuntu1~18.04.1) ...
# Removing dkms (2.3-3ubuntu9.7) ...
# Removing freeglut3-dev:amd64 (2.8.1-3) ...
# Removing freeglut3:amd64 (2.8.1-3) ...
# Removing xserver-xorg-core-hwe-18.04 (2:1.20.8-2ubuntu2.2~18.04.3) ...
# Removing keyboard-configuration (1.178ubuntu2.9) ...
# Removing screen-resolution-extra (0.17.3) ...
# Removing policykit-1-gnome (0.105-6ubuntu2) ...
# Removing policykit-1 (0.105-20ubuntu0.18.04.5) ...
# Removing libpam-systemd:amd64 (237-3ubuntu10.42) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Removing systemd-sysv (237-3ubuntu10.42) ...
# Removing systemd (237-3ubuntu10.42) ...
# Removing libcryptsetup12:amd64 (2:2.0.2-1ubuntu1.1) ...
# Removing libargon2-0:amd64 (0~20161029-1.1) ...
# Removing libcap2:amd64 (1:2.25-1.2) ...
# Removing libdevmapper1.02.1:amd64 (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Removing libxfont2:amd64 (1:2.0.3-1) ...
# Removing libfontenc1:amd64 (1:1.1.3-1) ...
# Removing libidn11:amd64 (1.33-2.1ubuntu1.2) ...
# Removing libip4tc0:amd64 (1.6.1-2ubuntu2) ...
# Removing libjansson4:amd64 (2.11-1) ...
# Removing libpolkit-agent-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Removing libpolkit-backend-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Removing libpolkit-gobject-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Removing libxi-dev:amd64 (2:1.7.9-1) ...
# Removing xserver-common (2:1.19.6-1ubuntu4.6) ...
# Removing x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Removing libxkbfile1:amd64 (1:1.0.9-2) ...
# Removing libxmu-dev:amd64 (2:1.1.2-2) ...
# Removing libxmu-headers (2:1.1.2-2) ...
# Removing libxnvctrl0:amd64 (455.23.05-0ubuntu1) ...
# Removing nsight-compute-2020.2.0 (2020.2.0.18-1) ...
# Removing nsight-systems-2020.3.4 (2020.3.4.32-52657a0) ...
# update-alternatives: removing manually selected alternative - switching nsys to auto mode
# update-alternatives: removing manually selected alternative - switching nsight-sys to auto mode
# update-alternatives: removing manually selected alternative - switching nsys-ui to auto mode
# dpkg: warning: while removing nsight-systems-2020.3.4, directory '/usr/local/bin' not empty so not removed
# dpkg: warning: while removing nsight-systems-2020.3.4, directory '/opt' not empty so not removed
# Removing ocl-icd-opencl-dev:amd64 (2.2.11-1ubuntu1) ...
# Removing opencl-c-headers (2.2~2018.02.21-gb5c3680-1) ...
# Removing openjdk-11-jre:amd64 (11.0.8+10-0ubuntu1~18.04.1) ...
# Removing python3-xkit (0.5.0ubuntu2) ...
# Removing udev (237-3ubuntu10.42) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.2) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...

# %% [markdown]
# # 安装CUDA 10.0

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-repo-ubuntu1804_10.0.130-1_amd64.deb
# !sudo dpkg -i cuda-repo-ubuntu1804_10.0.130-1_amd64.deb
# !sudo apt-key adv --fetch-keys https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/7fa2af80.pub
# !sudo apt-get update
# !wget http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64/nvidia-machine-learning-repo-ubuntu1804_1.0.0-1_amd64.deb
# !sudo apt install -y ./nvidia-machine-learning-repo-ubuntu1804_1.0.0-1_amd64.deb
# !sudo apt-get update
# Out:
# --2020-10-10 06:23:21--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-repo-ubuntu1804_10.0.130-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2940 (2.9K) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1804_10.0.130-1_amd64.deb’
#
# cuda-repo-ubuntu180 100%[===================>]   2.87K  --.-KB/s    in 0s
#
# 2020-10-10 06:23:22 (137 MB/s) - ‘cuda-repo-ubuntu1804_10.0.130-1_amd64.deb’ saved [2940/2940]
#
# Selecting previously unselected package cuda-repo-ubuntu1804.
# (Reading database ... 122380 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1804_10.0.130-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1804 (10.0.130-1) ...
# Setting up cuda-repo-ubuntu1804 (10.0.130-1) ...
#
# Configuration file '/etc/apt/sources.list.d/cuda.list'
#  ==> File on system created by you or by a script.
#  ==> File also in package provided by package maintainer.
#    What would you like to do about it ?  Your options are:
#     Y or I  : install the package maintainer's version
#     N or O  : keep your currently-installed version
#       D     : show the differences between the versions
#       Z     : start a shell to examine the situation
#  The default action is to keep your current version.
# *** cuda.list (Y/I/N/O/D/Z) [default=N] ? y
# Installing new version of config file /etc/apt/sources.list.d/cuda.list ...
# Executing: /tmp/apt-key-gpghome.2dEWr97ErO/gpg.1.sh --fetch-keys https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/7fa2af80.pub
# gpg: requesting key from 'https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/7fa2af80.pub'
# gpg: key F60F4B3D7FA2AF80: "cudatools <cudatools@nvidia.com>" not changed
# gpg: Total number processed: 1
# gpg:              unchanged: 1
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:8 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:9 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:10 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,693 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,341 kB]
# Get:15 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,675 kB]
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [857 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,104 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,110 kB]
# Ign:20 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:20 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [334 kB]
# Fetched 10.4 MB in 1s (8,055 kB/s)
# Reading package lists... Done
# --2020-10-10 06:23:35--  http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64/nvidia-machine-learning-repo-ubuntu1804_1.0.0-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2926 (2.9K) [application/x-deb]
# Saving to: ‘nvidia-machine-learning-repo-ubuntu1804_1.0.0-1_amd64.deb’
#
# nvidia-machine-lear 100%[===================>]   2.86K  --.-KB/s    in 0s
#
# 2020-10-10 06:23:35 (441 MB/s) - ‘nvidia-machine-learning-repo-ubuntu1804_1.0.0-1_amd64.deb’ saved [2926/2926]
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'nvidia-machine-learning-repo-ubuntu1804' instead of './nvidia-machine-learning-repo-ubuntu1804_1.0.0-1_amd64.deb'
# The following NEW packages will be installed:
#   nvidia-machine-learning-repo-ubuntu1804
# 0 upgraded, 1 newly installed, 0 to remove and 12 not upgraded.
# Need to get 2,926 B of archives.
# After this operation, 37.9 kB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  nvidia-machine-learning-repo-ubuntu1804 1.0.0-1 [2,926 B]
# Fetched 2,926 B in 0s (59.7 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nvidia-machine-learning-repo-ubuntu1804.
# (Reading database ... 122383 files and directories currently installed.)
# Preparing to unpack .../nvidia-machine-learning-repo-ubuntu1804_1.0.0-1_amd64.deb ...
# Unpacking nvidia-machine-learning-repo-ubuntu1804 (1.0.0-1) ...
# Setting up nvidia-machine-learning-repo-ubuntu1804 (1.0.0-1) ...
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:4 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Ign:7 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:8 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:9 http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:11 http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Reading package lists... Done
# W: Target Packages (Packages) is configured multiple times in /etc/apt/sources.list.d/nvidia-machine-learning.list:1 and /etc/apt/sources.list.d/nvidia-ml.list:1
# W: Target Packages (Packages) is configured multiple times in /etc/apt/sources.list.d/nvidia-machine-learning.list:1 and /etc/apt/sources.list.d/nvidia-ml.list:1

# %% [markdown]
# # 安装nvidia驱动

# %%
# !sudo apt-get -y install nvidia-driver-418
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   dkms dmsetup fakeroot keyboard-configuration libargon2-0 libcap2
#   libcryptsetup12 libdevmapper1.02.1 libfakeroot libfontenc1 libidn11
#   libip4tc0 libjansson4 libnss-systemd libnvidia-cfg1-455 libnvidia-common-455
#   libnvidia-compute-455 libnvidia-decode-455 libnvidia-encode-455
#   libnvidia-extra-455 libnvidia-fbc1-455 libnvidia-gl-455 libnvidia-ifr1-455
#   libpam-systemd libpolkit-agent-1-0 libpolkit-backend-1-0
#   libpolkit-gobject-1-0 libxfont2 libxkbfile1 libxnvctrl0 networkd-dispatcher
#   nvidia-compute-utils-455 nvidia-dkms-455 nvidia-driver-430 nvidia-driver-455
#   nvidia-kernel-common-455 nvidia-kernel-source-455 nvidia-prime
#   nvidia-settings nvidia-utils-455 policykit-1 policykit-1-gnome python3-xkit
#   screen-resolution-extra systemd systemd-sysv udev x11-xkb-utils xfonts-base
#   xfonts-encodings xfonts-utils xserver-common xserver-xorg-core-hwe-18.04
#   xserver-xorg-video-nvidia-455
# Suggested packages:
#   python3-apport menu iw | wireless-tools systemd-container xfs | xserver
#   xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libnvidia-compute-455:i386 libnvidia-decode-455:i386
#   libnvidia-encode-455:i386 libnvidia-ifr1-455:i386 libnvidia-fbc1-455:i386
#   libnvidia-gl-455:i386
# The following NEW packages will be installed:
#   dkms dmsetup fakeroot keyboard-configuration libargon2-0 libcap2
#   libcryptsetup12 libdevmapper1.02.1 libfakeroot libfontenc1 libidn11
#   libip4tc0 libjansson4 libnss-systemd libnvidia-cfg1-455 libnvidia-common-455
#   libnvidia-compute-455 libnvidia-decode-455 libnvidia-encode-455
#   libnvidia-extra-455 libnvidia-fbc1-455 libnvidia-gl-455 libnvidia-ifr1-455
#   libpam-systemd libpolkit-agent-1-0 libpolkit-backend-1-0
#   libpolkit-gobject-1-0 libxfont2 libxkbfile1 libxnvctrl0 networkd-dispatcher
#   nvidia-compute-utils-455 nvidia-dkms-455 nvidia-driver-418 nvidia-driver-430
#   nvidia-driver-455 nvidia-kernel-common-455 nvidia-kernel-source-455
#   nvidia-prime nvidia-settings nvidia-utils-455 policykit-1 policykit-1-gnome
#   python3-xkit screen-resolution-extra systemd systemd-sysv udev x11-xkb-utils
#   xfonts-base xfonts-encodings xfonts-utils xserver-common
#   xserver-xorg-core-hwe-18.04 xserver-xorg-video-nvidia-455
# 0 upgraded, 55 newly installed, 0 to remove and 12 not upgraded.
# Need to get 136 MB of archives.
# After this operation, 487 MB of additional disk space will be used.
# Get:1 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-cfg1-455 455.23.05-0ubuntu1 [75.2 kB]
# Get:2 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-common-455 455.23.05-0ubuntu1 [10.2 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 keyboard-configuration all 1.178ubuntu2.9 [369 kB]
# Get:4 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-compute-455 455.23.05-0ubuntu1 [22.1 MB]
# Get:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-driver-418 amd64 430.64-0ubuntu0~gpu18.04.1 [6,904 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcap2 amd64 1:2.25-1.2 [13.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libargon2-0 amd64 0~20161029-1.1 [19.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdevmapper1.02.1 amd64 2:1.02.145-4.1ubuntu3.18.04.3 [127 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcryptsetup12 amd64 2:2.0.2-1ubuntu1.1 [134 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libidn11 amd64 1.33-2.1ubuntu1.2 [46.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libip4tc0 amd64 1.6.1-2ubuntu2 [19.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 systemd amd64 237-3ubuntu10.42 [2,914 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 systemd-sysv amd64 237-3ubuntu10.42 [15.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dmsetup amd64 2:1.02.145-4.1ubuntu3.18.04.3 [74.4 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnss-systemd amd64 237-3ubuntu10.42 [105 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-systemd amd64 237-3ubuntu10.42 [107 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 networkd-dispatcher all 1.7-0ubuntu3.3 [13.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 udev amd64 237-3ubuntu10.42 [1,102 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpolkit-gobject-1-0 amd64 0.105-20ubuntu0.18.04.5 [36.4 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dkms all 2.3-3ubuntu9.7 [68.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfakeroot amd64 1.22-2ubuntu1 [25.9 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 fakeroot amd64 1.22-2ubuntu1 [62.3 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontenc1 amd64 1:1.1.3-1 [13.9 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjansson4 amd64 2.11-1 [29.3 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpolkit-agent-1-0 amd64 0.105-20ubuntu0.18.04.5 [14.9 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpolkit-backend-1-0 amd64 0.105-20ubuntu0.18.04.5 [36.3 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxkbfile1 amd64 1:1.0.9-2 [64.6 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 x11-xkb-utils amd64 7.7+3ubuntu0.18.04.1 [160 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-common all 2:1.19.6-1ubuntu4.6 [26.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-xorg-core-hwe-18.04 amd64 2:1.20.8-2ubuntu2.2~18.04.3 [1,334 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 nvidia-prime all 0.8.8.2 [8,412 B]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-xkit all 0.5.0ubuntu2 [18.6 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 policykit-1 amd64 0.105-20ubuntu0.18.04.5 [53.5 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 policykit-1-gnome amd64 0.105-6ubuntu2 [24.0 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 screen-resolution-extra all 0.17.3 [11.7 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-encodings all 1:1.0.4-2 [573 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-base all 1:1.0.4+nmu1 [5,914 kB]
# Get:40 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-decode-455 455.23.05-0ubuntu1 [1,216 kB]
# Get:41 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-encode-455 455.23.05-0ubuntu1 [39.6 kB]
# Get:42 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-extra-455 455.23.05-0ubuntu1 [39.8 kB]
# Get:43 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-fbc1-455 455.23.05-0ubuntu1 [46.4 kB]
# Get:44 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-gl-455 455.23.05-0ubuntu1 [76.5 MB]
# Get:45 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-ifr1-455 455.23.05-0ubuntu1 [68.5 kB]
# Get:46 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libxnvctrl0 455.23.05-0ubuntu1 [21.3 kB]
# Get:47 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-compute-utils-455 455.23.05-0ubuntu1 [106 kB]
# Get:48 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-kernel-source-455 455.23.05-0ubuntu1 [18.9 MB]
# Get:49 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-kernel-common-455 455.23.05-0ubuntu1 [19.4 kB]
# Get:50 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-dkms-455 455.23.05-0ubuntu1 [29.5 kB]
# Get:51 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-utils-455 455.23.05-0ubuntu1 [368 kB]
# Get:52 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  xserver-xorg-video-nvidia-455 455.23.05-0ubuntu1 [1,542 kB]
# Get:53 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-driver-455 455.23.05-0ubuntu1 [423 kB]
# Get:54 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-driver-430 455.23.05-0ubuntu1 [6,880 B]
# Get:55 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-settings 455.23.05-0ubuntu1 [921 kB]
# Fetched 136 MB in 2s (66.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 55.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package keyboard-configuration.
# (Reading database ... 122386 files and directories currently installed.)
# Preparing to unpack .../0-keyboard-configuration_1.178ubuntu2.9_all.deb ...
# Unpacking keyboard-configuration (1.178ubuntu2.9) ...
# Selecting previously unselected package libcap2:amd64.
# Preparing to unpack .../1-libcap2_1%3a2.25-1.2_amd64.deb ...
# Unpacking libcap2:amd64 (1:2.25-1.2) ...
# Selecting previously unselected package libargon2-0:amd64.
# Preparing to unpack .../2-libargon2-0_0~20161029-1.1_amd64.deb ...
# Unpacking libargon2-0:amd64 (0~20161029-1.1) ...
# Selecting previously unselected package libdevmapper1.02.1:amd64.
# Preparing to unpack .../3-libdevmapper1.02.1_2%3a1.02.145-4.1ubuntu3.18.04.3_amd64.deb ...
# Unpacking libdevmapper1.02.1:amd64 (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Selecting previously unselected package libcryptsetup12:amd64.
# Preparing to unpack .../4-libcryptsetup12_2%3a2.0.2-1ubuntu1.1_amd64.deb ...
# Unpacking libcryptsetup12:amd64 (2:2.0.2-1ubuntu1.1) ...
# Selecting previously unselected package libidn11:amd64.
# Preparing to unpack .../5-libidn11_1.33-2.1ubuntu1.2_amd64.deb ...
# Unpacking libidn11:amd64 (1.33-2.1ubuntu1.2) ...
# Selecting previously unselected package libip4tc0:amd64.
# Preparing to unpack .../6-libip4tc0_1.6.1-2ubuntu2_amd64.deb ...
# Unpacking libip4tc0:amd64 (1.6.1-2ubuntu2) ...
# Setting up libcap2:amd64 (1:2.25-1.2) ...
# Setting up libargon2-0:amd64 (0~20161029-1.1) ...
# Setting up libdevmapper1.02.1:amd64 (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Setting up libcryptsetup12:amd64 (2:2.0.2-1ubuntu1.1) ...
# Setting up libidn11:amd64 (1.33-2.1ubuntu1.2) ...
# Setting up libip4tc0:amd64 (1.6.1-2ubuntu2) ...
# Selecting previously unselected package systemd.
# (Reading database ... 122438 files and directories currently installed.)
# Preparing to unpack .../systemd_237-3ubuntu10.42_amd64.deb ...
# Unpacking systemd (237-3ubuntu10.42) ...
# Setting up systemd (237-3ubuntu10.42) ...
# Selecting previously unselected package systemd-sysv.
# (Reading database ... 123120 files and directories currently installed.)
# Preparing to unpack .../00-systemd-sysv_237-3ubuntu10.42_amd64.deb ...
# Unpacking systemd-sysv (237-3ubuntu10.42) ...
# Selecting previously unselected package dmsetup.
# Preparing to unpack .../01-dmsetup_2%3a1.02.145-4.1ubuntu3.18.04.3_amd64.deb ...
# Unpacking dmsetup (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Selecting previously unselected package libnss-systemd:amd64.
# Preparing to unpack .../02-libnss-systemd_237-3ubuntu10.42_amd64.deb ...
# Unpacking libnss-systemd:amd64 (237-3ubuntu10.42) ...
# Selecting previously unselected package libpam-systemd:amd64.
# Preparing to unpack .../03-libpam-systemd_237-3ubuntu10.42_amd64.deb ...
# Unpacking libpam-systemd:amd64 (237-3ubuntu10.42) ...
# Selecting previously unselected package networkd-dispatcher.
# Preparing to unpack .../04-networkd-dispatcher_1.7-0ubuntu3.3_all.deb ...
# Unpacking networkd-dispatcher (1.7-0ubuntu3.3) ...
# Selecting previously unselected package udev.
# Preparing to unpack .../05-udev_237-3ubuntu10.42_amd64.deb ...
# Unpacking udev (237-3ubuntu10.42) ...
# Selecting previously unselected package libpolkit-gobject-1-0:amd64.
# Preparing to unpack .../06-libpolkit-gobject-1-0_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking libpolkit-gobject-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package dkms.
# Preparing to unpack .../07-dkms_2.3-3ubuntu9.7_all.deb ...
# Unpacking dkms (2.3-3ubuntu9.7) ...
# Selecting previously unselected package libfakeroot:amd64.
# Preparing to unpack .../08-libfakeroot_1.22-2ubuntu1_amd64.deb ...
# Unpacking libfakeroot:amd64 (1.22-2ubuntu1) ...
# Selecting previously unselected package fakeroot.
# Preparing to unpack .../09-fakeroot_1.22-2ubuntu1_amd64.deb ...
# Unpacking fakeroot (1.22-2ubuntu1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../10-libfontenc1_1%3a1.1.3-1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.3-1) ...
# Selecting previously unselected package libjansson4:amd64.
# Preparing to unpack .../11-libjansson4_2.11-1_amd64.deb ...
# Unpacking libjansson4:amd64 (2.11-1) ...
# Selecting previously unselected package libnvidia-cfg1-455:amd64.
# Preparing to unpack .../12-libnvidia-cfg1-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-cfg1-455:amd64 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package libnvidia-common-455.
# Preparing to unpack .../13-libnvidia-common-455_455.23.05-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-455 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-455:amd64.
# Preparing to unpack .../14-libnvidia-compute-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-455:amd64 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package libnvidia-decode-455:amd64.
# Preparing to unpack .../15-libnvidia-decode-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-decode-455:amd64 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package libnvidia-encode-455:amd64.
# Preparing to unpack .../16-libnvidia-encode-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-encode-455:amd64 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package libnvidia-extra-455:amd64.
# Preparing to unpack .../17-libnvidia-extra-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-extra-455:amd64 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package libnvidia-fbc1-455:amd64.
# Preparing to unpack .../18-libnvidia-fbc1-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-fbc1-455:amd64 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package libnvidia-gl-455:amd64.
# Preparing to unpack .../19-libnvidia-gl-455_455.23.05-0ubuntu1_amd64.deb ...
# dpkg-query: no packages found matching libnvidia-gl-450
# Unpacking libnvidia-gl-455:amd64 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package libnvidia-ifr1-455:amd64.
# Preparing to unpack .../20-libnvidia-ifr1-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-ifr1-455:amd64 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package libpolkit-agent-1-0:amd64.
# Preparing to unpack .../21-libpolkit-agent-1-0_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking libpolkit-agent-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package libpolkit-backend-1-0:amd64.
# Preparing to unpack .../22-libpolkit-backend-1-0_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking libpolkit-backend-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../23-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../24-libxkbfile1_1%3a1.0.9-2_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.0.9-2) ...
# Selecting previously unselected package libxnvctrl0:amd64.
# Preparing to unpack .../25-libxnvctrl0_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking libxnvctrl0:amd64 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package nvidia-compute-utils-455.
# Preparing to unpack .../26-nvidia-compute-utils-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-compute-utils-455 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-source-455.
# Preparing to unpack .../27-nvidia-kernel-source-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-source-455 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-common-455.
# Preparing to unpack .../28-nvidia-kernel-common-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-common-455 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package nvidia-dkms-455.
# Preparing to unpack .../29-nvidia-dkms-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-dkms-455 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package nvidia-utils-455.
# Preparing to unpack .../30-nvidia-utils-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-utils-455 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../31-x11-xkb-utils_7.7+3ubuntu0.18.04.1_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../32-xserver-common_2%3a1.19.6-1ubuntu4.6_all.deb ...
# Unpacking xserver-common (2:1.19.6-1ubuntu4.6) ...
# Selecting previously unselected package xserver-xorg-core-hwe-18.04.
# Preparing to unpack .../33-xserver-xorg-core-hwe-18.04_2%3a1.20.8-2ubuntu2.2~18.04.3_amd64.deb ...
# Unpacking xserver-xorg-core-hwe-18.04 (2:1.20.8-2ubuntu2.2~18.04.3) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-455.
# Preparing to unpack .../34-xserver-xorg-video-nvidia-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-455 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-455.
# Preparing to unpack .../35-nvidia-driver-455_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-455 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-430.
# Preparing to unpack .../36-nvidia-driver-430_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-430 (455.23.05-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-418.
# Preparing to unpack .../37-nvidia-driver-418_430.64-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-driver-418 (430.64-0ubuntu0~gpu18.04.1) ...
# Selecting previously unselected package nvidia-prime.
# Preparing to unpack .../38-nvidia-prime_0.8.8.2_all.deb ...
# Unpacking nvidia-prime (0.8.8.2) ...
# Selecting previously unselected package python3-xkit.
# Preparing to unpack .../39-python3-xkit_0.5.0ubuntu2_all.deb ...
# Unpacking python3-xkit (0.5.0ubuntu2) ...
# Selecting previously unselected package policykit-1.
# Preparing to unpack .../40-policykit-1_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking policykit-1 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package policykit-1-gnome.
# Preparing to unpack .../41-policykit-1-gnome_0.105-6ubuntu2_amd64.deb ...
# Unpacking policykit-1-gnome (0.105-6ubuntu2) ...
# Selecting previously unselected package screen-resolution-extra.
# Preparing to unpack .../42-screen-resolution-extra_0.17.3_all.deb ...
# Unpacking screen-resolution-extra (0.17.3) ...
# Selecting previously unselected package nvidia-settings.
# Preparing to unpack .../43-nvidia-settings_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (455.23.05-0ubuntu1) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../44-xfonts-encodings_1%3a1.0.4-2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.4-2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../45-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../46-xfonts-base_1%3a1.0.4+nmu1_all.deb ...
# Unpacking xfonts-base (1:1.0.4+nmu1) ...
# Setting up libxkbfile1:amd64 (1:1.0.9-2) ...
# Setting up nvidia-kernel-common-455 (455.23.05-0ubuntu1) ...
# Setting up libnss-systemd:amd64 (237-3ubuntu10.42) ...
# First installation detected...
# Checking NSS setup...
# Setting up keyboard-configuration (1.178ubuntu2.9) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Configuring keyboard-configuration
# ----------------------------------
#
# The layout of keyboards varies per country, with some countries having multiple
# common layouts. Please select the country of origin for the keyboard of this
# computer.
#
#   1. Afghani
#   2. Albanian
#   3. Amharic
#   4. Arabic
#   5. Arabic (Morocco)
#   6. Arabic (Syria)
#   7. Armenian
#   8. Azerbaijani
#   9. Bambara
#   10. Bangla
#   11. Belarusian
#   12. Belgian
#   13. Berber (Algeria, Latin)
#   14. Bosnian
#   15. Braille
#   16. Bulgarian
#   17. Burmese
#   18. Chinese
#   19. Croatian
#   20. Czech
#   21. Danish
#   22. Dhivehi
#   23. Dutch
#   24. Dzongkha
#   25. English (Australian)
#   26. English (Cameroon)
#   27. English (Ghana)
#   28. English (Nigeria)
#   29. English (South Africa)
#   30. English (UK)
#   31. English (US)
#   32. Esperanto
#   33. Estonian
#   34. Faroese
#   35. Filipino
#   36. Finnish
#   37. French
#   38. French (Canada)
#   39. French (Democratic Republic of the Congo)
#   40. French (Guinea)
#   41. French (Togo)
#   42. Georgian
#   43. German
#   44. German (Austria)
#   45. Greek
#   46. Hebrew
#   47. Hungarian
#   48. Icelandic
#   49. Indian
#   50. Indonesian (Jawi)
#   51. Iraqi
#   52. Irish
#   53. Italian
#   54. Japanese
#   55. Japanese (PC-98)
#   56. Kazakh
#   57. Khmer (Cambodia)
#   58. Korean
#   59. Kyrgyz
#   60. Lao
#   61. Latvian
#   62. Lithuanian
#   63. Macedonian
#   64. Malay (Jawi, Arabic Keyboard)
#   65. Maltese
#   66. Maori
#   67. Moldavian
#   68. Mongolian
#   69. Montenegrin
#   70. Nepali
#   71. Norwegian
#   72. Persian
#   73. Polish
#   74. Portuguese
#   75. Portuguese (Brazil)
#   76. Romanian
#   77. Russian
#   78. Serbian
#   79. Sinhala (phonetic)
#   80. Slovak
#   81. Slovenian
#   82. Spanish
#   83. Spanish (Latin American)
#   84. Swahili (Kenya)
#   85. Swahili (Tanzania)
#   86. Swedish
#   87. Switzerland
#   88. Taiwanese
#   89. Tajik
#   90. Thai
#   91. Tswana
#   92. Turkish
#   93. Turkmen
#   94. Ukrainian
#   95. Urdu (Pakistan)
#   96. Uzbek
#   97. Vietnamese
#   98. Wolof
# Country of origin for the keyboard: 31
#
# Please select the layout matching the keyboard for this machine.
#
#   1. English (US)
#   2. English (US) - Cherokee
#   3. English (US) - English (classic Dvorak)
#   4. English (US) - English (Colemak)
#   5. English (US) - English (Dvorak)
#   6. English (US) - English (Dvorak, alt. intl.)
#   7. English (US) - English (Dvorak, intl., with dead keys)
#   8. English (US) - English (Dvorak, left-handed)
#   9. English (US) - English (Dvorak, right-handed)
#   10. English (US) - English (intl., with AltGr dead keys)
#   11. English (US) - English (Macintosh)
#   12. English (US) - English (programmer Dvorak)
#   13. English (US) - English (the divide/multiply keys toggle the layout)
#   14. English (US) - English (US, alt. intl.)
#   15. English (US) - English (US, euro on 5)
#   16. English (US) - English (US, intl., with dead keys)
#   17. English (US) - English (Workman)
#   18. English (US) - English (Workman, intl., with dead keys)
#   19. English (US) - Russian (US, phonetic)
#   20. English (US) - Serbo-Croatian (US)
# Keyboard layout: 1
#
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up nvidia-prime (0.8.8.2) ...
# Setting up x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Setting up systemd-sysv (237-3ubuntu10.42) ...
# Setting up libjansson4:amd64 (2.11-1) ...
# Setting up xfonts-encodings (1:1.0.4-2) ...
# Setting up libnvidia-extra-455:amd64 (455.23.05-0ubuntu1) ...
# Setting up dkms (2.3-3ubuntu9.7) ...
# Setting up udev (237-3ubuntu10.42) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of restart.
# Setting up libnvidia-cfg1-455:amd64 (455.23.05-0ubuntu1) ...
# Setting up libnvidia-compute-455:amd64 (455.23.05-0ubuntu1) ...
# Setting up libfakeroot:amd64 (1.22-2ubuntu1) ...
# Setting up libfontenc1:amd64 (1:1.1.3-1) ...
# Setting up dmsetup (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Setting up libnvidia-common-455 (455.23.05-0ubuntu1) ...
# Setting up nvidia-kernel-source-455 (455.23.05-0ubuntu1) ...
# Setting up nvidia-dkms-455 (455.23.05-0ubuntu1) ...
#
# A modprobe blacklist file has been created at /etc/modprobe.d to prevent Nouveau
# from loading. This can be reverted by deleting the following file:
# /etc/modprobe.d/nvidia-graphics-drivers.conf
#
# A new initrd image has also been created. To revert, please regenerate your
# initrd by running the following command after deleting the modprobe.d file:
# `/usr/sbin/initramfs -u`
#
# *****************************************************************************
# *** Reboot your computer and verify that the NVIDIA graphics driver can   ***
# *** be loaded.                                                            ***
# *****************************************************************************
#
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Loading new nvidia-455.23.05 DKMS files...
# It is likely that 4.19.112+ belongs to a chroot's host
# Building for 4.15.0-118-generic
# Building for architecture x86_64
# Building initial module for 4.15.0-118-generic
# Done.
#
# nvidia:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-118-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-118-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-118-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-118-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Setting up libxnvctrl0:amd64 (455.23.05-0ubuntu1) ...
# Setting up libnvidia-fbc1-455:amd64 (455.23.05-0ubuntu1) ...
# Setting up networkd-dispatcher (1.7-0ubuntu3.3) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/networkd-dispatcher.service → /lib/systemd/system/networkd-dispatcher.service.
# Setting up libpolkit-gobject-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Setting up python3-xkit (0.5.0ubuntu2) ...
# Setting up nvidia-utils-455 (455.23.05-0ubuntu1) ...
# Setting up xserver-common (2:1.19.6-1ubuntu4.6) ...
# Setting up libpam-systemd:amd64 (237-3ubuntu10.42) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up libnvidia-decode-455:amd64 (455.23.05-0ubuntu1) ...
# Setting up libpolkit-agent-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Setting up nvidia-compute-utils-455 (455.23.05-0ubuntu1) ...
# Warning: The home dir /nonexistent you specified can't be accessed: No such file or directory
# Adding system user `nvidia-persistenced' (UID 103) ...
# Adding new group `nvidia-persistenced' (GID 106) ...
# Adding new user `nvidia-persistenced' (UID 103) with group `nvidia-persistenced' ...
# Not creating home directory `/nonexistent'.
# Created symlink /etc/systemd/system/multi-user.target.wants/nvidia-persistenced.service → /lib/systemd/system/nvidia-persistenced.service.
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up fakeroot (1.22-2ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# Setting up libnvidia-gl-455:amd64 (455.23.05-0ubuntu1) ...
# Setting up libpolkit-backend-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Setting up libnvidia-encode-455:amd64 (455.23.05-0ubuntu1) ...
# Setting up xserver-xorg-core-hwe-18.04 (2:1.20.8-2ubuntu2.2~18.04.3) ...
# Setting up xfonts-base (1:1.0.4+nmu1) ...
# Setting up libnvidia-ifr1-455:amd64 (455.23.05-0ubuntu1) ...
# Setting up policykit-1 (0.105-20ubuntu0.18.04.5) ...
# Setting up policykit-1-gnome (0.105-6ubuntu2) ...
# Setting up screen-resolution-extra (0.17.3) ...
# Setting up xserver-xorg-video-nvidia-455 (455.23.05-0ubuntu1) ...
# Setting up nvidia-driver-455 (455.23.05-0ubuntu1) ...
# Setting up nvidia-settings (455.23.05-0ubuntu1) ...
# Setting up nvidia-driver-430 (455.23.05-0ubuntu1) ...
# Setting up nvidia-driver-418 (430.64-0ubuntu0~gpu18.04.1) ...
# Processing triggers for systemd (237-3ubuntu10.42) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# W: Target Packages (Packages) is configured multiple times in /etc/apt/sources.list.d/nvidia-machine-learning.list:1 and /etc/apt/sources.list.d/nvidia-ml.list:1

# %% [markdown]
# # 安装CUDNN

# %%
# !sudo apt-get install -y \
    cuda-10-0 \
    libcudnn7=7.6.2.24-1+cuda10.0  \
    libcudnn7-dev=7.6.2.24-1+cuda10.0 --allow-change-held-packages
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cuda-command-line-tools-10-0 cuda-compiler-10-0 cuda-cuobjdump-10-0
#   cuda-cupti-10-0 cuda-demo-suite-10-0 cuda-documentation-10-0 cuda-drivers
#   cuda-drivers-455 cuda-gdb-10-0 cuda-gpu-library-advisor-10-0
#   cuda-libraries-10-0 cuda-memcheck-10-0 cuda-nsight-10-0
#   cuda-nsight-compute-10-0 cuda-nvcc-10-0 cuda-nvdisasm-10-0
#   cuda-nvml-dev-10-0 cuda-nvprof-10-0 cuda-nvprune-10-0 cuda-nvtx-10-0
#   cuda-nvvp-10-0 cuda-runtime-10-0 cuda-samples-10-0 cuda-toolkit-10-0
#   cuda-tools-10-0 cuda-visual-tools-10-0 default-jre fonts-dejavu-core
#   fonts-dejavu-extra freeglut3 freeglut3-dev libatk-wrapper-java
#   libatk-wrapper-java-jni libxi-dev libxmu-dev libxmu-headers libxxf86dga1
#   nvidia-modprobe openjdk-11-jre x11-utils
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   cuda-10-0 cuda-command-line-tools-10-0 cuda-compiler-10-0
#   cuda-cuobjdump-10-0 cuda-cupti-10-0 cuda-demo-suite-10-0
#   cuda-documentation-10-0 cuda-drivers cuda-drivers-455 cuda-gdb-10-0
#   cuda-gpu-library-advisor-10-0 cuda-libraries-10-0 cuda-memcheck-10-0
#   cuda-nsight-10-0 cuda-nsight-compute-10-0 cuda-nvcc-10-0 cuda-nvdisasm-10-0
#   cuda-nvml-dev-10-0 cuda-nvprof-10-0 cuda-nvprune-10-0 cuda-nvtx-10-0
#   cuda-nvvp-10-0 cuda-runtime-10-0 cuda-samples-10-0 cuda-toolkit-10-0
#   cuda-tools-10-0 cuda-visual-tools-10-0 default-jre fonts-dejavu-core
#   fonts-dejavu-extra freeglut3 freeglut3-dev libatk-wrapper-java
#   libatk-wrapper-java-jni libxi-dev libxmu-dev libxmu-headers libxxf86dga1
#   nvidia-modprobe openjdk-11-jre x11-utils
# The following held packages will be changed:
#   libcudnn7
# The following packages will be DOWNGRADED:
#   libcudnn7 libcudnn7-dev
# 0 upgraded, 41 newly installed, 2 downgraded, 0 to remove and 10 not upgraded.
# Need to get 1,073 MB of archives.
# After this operation, 1,464 MB of additional disk space will be used.
# Get:1 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvcc-10-0 10.0.130-1 [20.0 MB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jre amd64 11.0.8+10-0ubuntu1~18.04.1 [34.4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 default-jre amd64 2:1.11-68ubuntu1~18.04.1 [1,076 B]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3-dev amd64 2.8.1-3 [124 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmu-headers all 2:1.1.2-2 [54.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmu-dev amd64 2:1.1.2-2 [49.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxi-dev amd64 2:1.7.9-1 [186 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java all 0.33.3-20ubuntu0.1 [34.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java-jni amd64 0.33.3-20ubuntu0.1 [28.3 kB]
# Get:15 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-cuobjdump-10-0 10.0.130-1 [130 kB]
# Get:16 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvprune-10-0 10.0.130-1 [36.8 kB]
# Get:17 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-compiler-10-0 10.0.130-1 [2,538 B]
# Get:18 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvdisasm-10-0 10.0.130-1 [22.1 MB]
# Get:19 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-gdb-10-0 10.0.130-1 [2,769 kB]
# Get:20 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvprof-10-0 10.0.130-1 [5,590 kB]
# Get:21 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-memcheck-10-0 10.0.130-1 [139 kB]
# Get:22 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-cupti-10-0 10.0.130-1 [1,564 kB]
# Get:23 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-gpu-library-advisor-10-0 10.0.130-1 [1,003 kB]
# Get:24 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvtx-10-0 10.0.130-1 [38.9 kB]
# Get:25 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-command-line-tools-10-0 10.0.130-1 [26.9 kB]
# Get:26 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nsight-10-0 10.0.130-1 [2,590 B]
# Get:27 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvvp-10-0 10.0.130-1 [2,536 B]
# Get:28 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nvml-dev-10-0 10.0.130-1 [51.6 kB]
# Get:29 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-nsight-compute-10-0 10.0.130-1 [188 MB]
# Get:30 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-visual-tools-10-0 10.0.130-1 [394 MB]
# Get:31 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-tools-10-0 10.0.130-1 [2,498 B]
# Get:32 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-samples-10-0 10.0.130-1 [61.5 MB]
# Get:33 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-documentation-10-0 10.0.130-1 [52.0 MB]
# Get:34 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-toolkit-10-0 10.0.130-1 [2,834 B]
# Get:35 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-modprobe 455.23.05-0ubuntu1 [19.8 kB]
# Get:36 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-drivers-455 455.23.05-1 [2,624 B]
# Get:37 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-drivers 455.23.05-1 [2,496 B]
# Get:38 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-libraries-10-0 10.0.130-1 [2,586 B]
# Get:39 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-runtime-10-0 10.0.130-1 [2,540 B]
# Get:40 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-demo-suite-10-0 10.0.130-1 [3,868 kB]
# Get:41 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-10-0 10.0.130-1 [2,562 B]
# Get:42 http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  libcudnn7-dev 7.6.2.24-1+cuda10.0 [152 MB]
# Get:43 http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  libcudnn7 7.6.2.24-1+cuda10.0 [164 MB]
# Fetched 1,073 MB in 28s (38.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 43.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 124687 files and directories currently installed.)
# Preparing to unpack .../00-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package cuda-nvcc-10-0.
# Preparing to unpack .../01-cuda-nvcc-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-nvcc-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-cuobjdump-10-0.
# Preparing to unpack .../02-cuda-cuobjdump-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-cuobjdump-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-nvprune-10-0.
# Preparing to unpack .../03-cuda-nvprune-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-nvprune-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-compiler-10-0.
# Preparing to unpack .../04-cuda-compiler-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-compiler-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-nvdisasm-10-0.
# Preparing to unpack .../05-cuda-nvdisasm-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-nvdisasm-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-gdb-10-0.
# Preparing to unpack .../06-cuda-gdb-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-gdb-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-nvprof-10-0.
# Preparing to unpack .../07-cuda-nvprof-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-nvprof-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-memcheck-10-0.
# Preparing to unpack .../08-cuda-memcheck-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-memcheck-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-cupti-10-0.
# Preparing to unpack .../09-cuda-cupti-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-cupti-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-gpu-library-advisor-10-0.
# Preparing to unpack .../10-cuda-gpu-library-advisor-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-gpu-library-advisor-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-nvtx-10-0.
# Preparing to unpack .../11-cuda-nvtx-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-nvtx-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-command-line-tools-10-0.
# Preparing to unpack .../12-cuda-command-line-tools-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-command-line-tools-10-0 (10.0.130-1) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../13-openjdk-11-jre_11.0.8+10-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.8+10-0ubuntu1~18.04.1) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../14-default-jre_2%3a1.11-68ubuntu1~18.04.1_amd64.deb ...
# Unpacking default-jre (2:1.11-68ubuntu1~18.04.1) ...
# Selecting previously unselected package cuda-nsight-10-0.
# Preparing to unpack .../15-cuda-nsight-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-nsight-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-nvvp-10-0.
# Preparing to unpack .../16-cuda-nvvp-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-nvvp-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-nvml-dev-10-0.
# Preparing to unpack .../17-cuda-nvml-dev-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-nvml-dev-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-nsight-compute-10-0.
# Preparing to unpack .../18-cuda-nsight-compute-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-nsight-compute-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-visual-tools-10-0.
# Preparing to unpack .../19-cuda-visual-tools-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-visual-tools-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-tools-10-0.
# Preparing to unpack .../20-cuda-tools-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-tools-10-0 (10.0.130-1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../21-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../22-freeglut3-dev_2.8.1-3_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-3) ...
# Selecting previously unselected package libxmu-headers.
# Preparing to unpack .../23-libxmu-headers_2%3a1.1.2-2_all.deb ...
# Unpacking libxmu-headers (2:1.1.2-2) ...
# Selecting previously unselected package libxmu-dev:amd64.
# Preparing to unpack .../24-libxmu-dev_2%3a1.1.2-2_amd64.deb ...
# Unpacking libxmu-dev:amd64 (2:1.1.2-2) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../25-libxi-dev_2%3a1.7.9-1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.7.9-1) ...
# Selecting previously unselected package cuda-samples-10-0.
# Preparing to unpack .../26-cuda-samples-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-samples-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-documentation-10-0.
# Preparing to unpack .../27-cuda-documentation-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-documentation-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-toolkit-10-0.
# Preparing to unpack .../28-cuda-toolkit-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-toolkit-10-0 (10.0.130-1) ...
# Selecting previously unselected package nvidia-modprobe.
# Preparing to unpack .../29-nvidia-modprobe_455.23.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (455.23.05-0ubuntu1) ...
# Selecting previously unselected package cuda-drivers-455.
# Preparing to unpack .../30-cuda-drivers-455_455.23.05-1_amd64.deb ...
# Unpacking cuda-drivers-455 (455.23.05-1) ...
# Selecting previously unselected package cuda-drivers.
# Preparing to unpack .../31-cuda-drivers_455.23.05-1_amd64.deb ...
# Unpacking cuda-drivers (455.23.05-1) ...
# Selecting previously unselected package cuda-libraries-10-0.
# Preparing to unpack .../32-cuda-libraries-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-libraries-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-runtime-10-0.
# Preparing to unpack .../33-cuda-runtime-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-runtime-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-demo-suite-10-0.
# Preparing to unpack .../34-cuda-demo-suite-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-demo-suite-10-0 (10.0.130-1) ...
# Selecting previously unselected package cuda-10-0.
# Preparing to unpack .../35-cuda-10-0_10.0.130-1_amd64.deb ...
# Unpacking cuda-10-0 (10.0.130-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../36-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../37-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../38-x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../39-libatk-wrapper-java_0.33.3-20ubuntu0.1_all.deb ...
# Unpacking libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../40-libatk-wrapper-java-jni_0.33.3-20ubuntu0.1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# dpkg: warning: downgrading libcudnn7-dev from 7.6.5.32-1+cuda10.1 to 7.6.2.24-1+cuda10.0
# Preparing to unpack .../41-libcudnn7-dev_7.6.2.24-1+cuda10.0_amd64.deb ...
# update-alternatives: removing manually selected alternative - switching libcudnn to auto mode
# Unpacking libcudnn7-dev (7.6.2.24-1+cuda10.0) over (7.6.5.32-1+cuda10.1) ...
# dpkg: warning: downgrading libcudnn7 from 7.6.5.32-1+cuda10.1 to 7.6.2.24-1+cuda10.0
# Preparing to unpack .../42-libcudnn7_7.6.2.24-1+cuda10.0_amd64.deb ...
# Unpacking libcudnn7 (7.6.2.24-1+cuda10.0) over (7.6.5.32-1+cuda10.1) ...
# Setting up libcudnn7 (7.6.2.24-1+cuda10.0) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up cuda-nvprune-10-0 (10.0.130-1) ...
# Setting up cuda-cuobjdump-10-0 (10.0.130-1) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up cuda-nsight-compute-10-0 (10.0.130-1) ...
# Setting up libxmu-headers (2:1.1.2-2) ...
# Setting up libcudnn7-dev (7.6.2.24-1+cuda10.0) ...
# update-alternatives: using /usr/include/x86_64-linux-gnu/cudnn_v7.h to provide /usr/include/cudnn.h (libcudnn) in auto mode
# Setting up cuda-libraries-10-0 (10.0.130-1) ...
# Setting up cuda-gpu-library-advisor-10-0 (10.0.130-1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up cuda-memcheck-10-0 (10.0.130-1) ...
# Setting up nvidia-modprobe (455.23.05-0ubuntu1) ...
# Setting up cuda-drivers-455 (455.23.05-1) ...
# Setting up cuda-nvdisasm-10-0 (10.0.130-1) ...
# Setting up cuda-nvml-dev-10-0 (10.0.130-1) ...
# Setting up libxi-dev:amd64 (2:1.7.9-1) ...
# Setting up cuda-nvcc-10-0 (10.0.130-1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Setting up cuda-nvprof-10-0 (10.0.130-1) ...
# Setting up cuda-nvtx-10-0 (10.0.130-1) ...
# Setting up freeglut3-dev:amd64 (2.8.1-3) ...
# Setting up openjdk-11-jre:amd64 (11.0.8+10-0ubuntu1~18.04.1) ...
# Setting up cuda-gdb-10-0 (10.0.130-1) ...
# Setting up libxmu-dev:amd64 (2:1.1.2-2) ...
# Setting up cuda-samples-10-0 (10.0.130-1) ...
# Setting up default-jre (2:1.11-68ubuntu1~18.04.1) ...
# Setting up cuda-cupti-10-0 (10.0.130-1) ...
# Setting up cuda-command-line-tools-10-0 (10.0.130-1) ...
# Setting up x11-utils (7.7+3build1) ...
# Setting up cuda-nvvp-10-0 (10.0.130-1) ...
# Setting up cuda-drivers (455.23.05-1) ...
# Setting up cuda-documentation-10-0 (10.0.130-1) ...
# Setting up cuda-compiler-10-0 (10.0.130-1) ...
# Setting up cuda-nsight-10-0 (10.0.130-1) ...
# Setting up libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Setting up cuda-runtime-10-0 (10.0.130-1) ...
# Setting up cuda-demo-suite-10-0 (10.0.130-1) ...
# Setting up cuda-visual-tools-10-0 (10.0.130-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Setting up cuda-tools-10-0 (10.0.130-1) ...
# Setting up cuda-toolkit-10-0 (10.0.130-1) ...
# Setting up cuda-10-0 (10.0.130-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# W: Target Packages (Packages) is configured multiple times in /etc/apt/sources.list.d/nvidia-machine-learning.list:1 and /etc/apt/sources.list.d/nvidia-ml.list:1

# %% [markdown]
# # 检查CUDA是否已经改变了版本

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %% [markdown]
# # 安装TensorRT

# %%
# !sudo dpkg -i "nv-tensorrt-repo-ubuntu1804-cuda10.0-trt7.0.0.11-ga-20191216_1-1_amd64.deb"
# !sudo apt-key add /var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216/7fa2af80.pub

# !sudo apt-get update
# Out:
# Selecting previously unselected package nv-tensorrt-repo-ubuntu1804-cuda10.0-trt7.0.0.11-ga-20191216.
# (Reading database ... 134422 files and directories currently installed.)
# Preparing to unpack nv-tensorrt-repo-ubuntu1804-cuda10.0-trt7.0.0.11-ga-20191216_1-1_amd64.deb ...
# Unpacking nv-tensorrt-repo-ubuntu1804-cuda10.0-trt7.0.0.11-ga-20191216 (1-1) ...
# Setting up nv-tensorrt-repo-ubuntu1804-cuda10.0-trt7.0.0.11-ga-20191216 (1-1) ...
# OK
# Get:1 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  InRelease
# Ign:1 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  InRelease
# Get:2 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  Release [574 B]
# Get:2 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  Release [574 B]
# Get:3 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  Release.gpg [836 B]
# Get:3 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  Release.gpg [836 B]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:11 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  Packages [4,789 B]
# Ign:12 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:13 http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:14 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:15 http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Fetched 252 kB in 1s (326 kB/s)
# Reading package lists... Done
# W: Target Packages (Packages) is configured multiple times in /etc/apt/sources.list.d/nvidia-machine-learning.list:1 and /etc/apt/sources.list.d/nvidia-ml.list:1
# W: Target Packages (Packages) is configured multiple times in /etc/apt/sources.list.d/nvidia-machine-learning.list:1 and /etc/apt/sources.list.d/nvidia-ml.list:1

# %% [markdown]
# # 安装依赖包

# %%
# !sudo apt-get install libnvinfer7=7.0.0-1+cuda10.0 libnvonnxparsers7=7.0.0-1+cuda10.0 libnvparsers7=7.0.0-1+cuda10.0 libnvinfer-plugin7=7.0.0-1+cuda10.0 libnvinfer-dev=7.0.0-1+cuda10.0 libnvonnxparsers-dev=7.0.0-1+cuda10.0 libnvparsers-dev=7.0.0-1+cuda10.0 libnvinfer-plugin-dev=7.0.0-1+cuda10.0 python-libnvinfer=7.0.0-1+cuda10.0 python3-libnvinfer=7.0.0-1+cuda10.0

# !sudo apt-mark hold libnvinfer7 libnvonnxparsers7 libnvparsers7 libnvinfer-plugin7 libnvinfer-dev libnvonnxparsers-dev libnvparsers-dev libnvinfer-plugin-dev python-libnvinfer python3-libnvinfer
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   libnvinfer-dev libnvinfer-plugin-dev libnvinfer-plugin7 libnvinfer7
#   libnvonnxparsers-dev libnvonnxparsers7 libnvparsers-dev libnvparsers7
#   python-libnvinfer python3-libnvinfer
# 0 upgraded, 10 newly installed, 0 to remove and 12 not upgraded.
# Need to get 0 B/148 MB of archives.
# After this operation, 544 MB of additional disk space will be used.
# Get:1 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvinfer7 7.0.0-1+cuda10.0 [69.6 MB]
# Get:2 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvinfer-dev 7.0.0-1+cuda10.0 [71.6 MB]
# Get:3 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvinfer-plugin7 7.0.0-1+cuda10.0 [2,109 kB]
# Get:4 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvinfer-plugin-dev 7.0.0-1+cuda10.0 [2,177 kB]
# Get:5 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvonnxparsers7 7.0.0-1+cuda10.0 [593 kB]
# Get:6 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvonnxparsers-dev 7.0.0-1+cuda10.0 [295 kB]
# Get:7 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvparsers7 7.0.0-1+cuda10.0 [791 kB]
# Get:8 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvparsers-dev 7.0.0-1+cuda10.0 [540 kB]
# Get:9 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  python-libnvinfer 7.0.0-1+cuda10.0 [359 kB]
# Get:10 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  python3-libnvinfer 7.0.0-1+cuda10.0 [355 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 10.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libnvinfer7.
# (Reading database ... 134450 files and directories currently installed.)
# Preparing to unpack .../0-libnvinfer7_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking libnvinfer7 (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package libnvinfer-dev.
# Preparing to unpack .../1-libnvinfer-dev_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking libnvinfer-dev (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package libnvinfer-plugin7.
# Preparing to unpack .../2-libnvinfer-plugin7_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking libnvinfer-plugin7 (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package libnvinfer-plugin-dev.
# Preparing to unpack .../3-libnvinfer-plugin-dev_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking libnvinfer-plugin-dev (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package libnvonnxparsers7.
# Preparing to unpack .../4-libnvonnxparsers7_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking libnvonnxparsers7 (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package libnvonnxparsers-dev.
# Preparing to unpack .../5-libnvonnxparsers-dev_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking libnvonnxparsers-dev (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package libnvparsers7.
# Preparing to unpack .../6-libnvparsers7_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking libnvparsers7 (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package libnvparsers-dev.
# Preparing to unpack .../7-libnvparsers-dev_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking libnvparsers-dev (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package python-libnvinfer.
# Preparing to unpack .../8-python-libnvinfer_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking python-libnvinfer (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package python3-libnvinfer.
# Preparing to unpack .../9-python3-libnvinfer_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking python3-libnvinfer (7.0.0-1+cuda10.0) ...
# Setting up libnvinfer7 (7.0.0-1+cuda10.0) ...
# Setting up libnvinfer-dev (7.0.0-1+cuda10.0) ...
# Setting up libnvinfer-plugin7 (7.0.0-1+cuda10.0) ...
# Setting up libnvparsers7 (7.0.0-1+cuda10.0) ...
# Setting up libnvonnxparsers7 (7.0.0-1+cuda10.0) ...
# Setting up python-libnvinfer (7.0.0-1+cuda10.0) ...
# Setting up libnvinfer-plugin-dev (7.0.0-1+cuda10.0) ...
# Setting up libnvparsers-dev (7.0.0-1+cuda10.0) ...
# Setting up python3-libnvinfer (7.0.0-1+cuda10.0) ...
# Setting up libnvonnxparsers-dev (7.0.0-1+cuda10.0) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# W: Target Packages (Packages) is configured multiple times in /etc/apt/sources.list.d/nvidia-machine-learning.list:1 and /etc/apt/sources.list.d/nvidia-ml.list:1
# libnvinfer7 set on hold.
# libnvonnxparsers7 set on hold.
# libnvparsers7 set on hold.
# libnvinfer-plugin7 set on hold.
# libnvinfer-dev set on hold.
# libnvonnxparsers-dev set on hold.
# libnvparsers-dev set on hold.
# libnvinfer-plugin-dev set on hold.
# python-libnvinfer set on hold.
# python3-libnvinfer set on hold.
# W: Target Packages (Packages) is configured multiple times in /etc/apt/sources.list.d/nvidia-machine-learning.list:1 and /etc/apt/sources.list.d/nvidia-ml.list:1

# %%
# !sudo apt-get install tensorrt
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libnvinfer-bin libnvinfer-doc libnvinfer-samples
# The following NEW packages will be installed:
#   libnvinfer-bin libnvinfer-doc libnvinfer-samples tensorrt
# 0 upgraded, 4 newly installed, 0 to remove and 22 not upgraded.
# Need to get 0 B/462 MB of archives.
# After this operation, 590 MB of additional disk space will be used.
# Get:1 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvinfer-bin 7.0.0-1+cuda10.0 [94.7 kB]
# Get:2 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvinfer-doc 7.0.0-1+cuda10.0 [9,717 kB]
# Get:3 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  libnvinfer-samples 7.0.0-1+cuda10.0 [452 MB]
# Get:4 file:/var/nv-tensorrt-repo-cuda10.0-trt7.0.0.11-ga-20191216  tensorrt 7.0.0.11-1+cuda10.0 [3,652 B]
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libnvinfer-bin.
# (Reading database ... 134562 files and directories currently installed.)
# Preparing to unpack .../libnvinfer-bin_7.0.0-1+cuda10.0_amd64.deb ...
# Unpacking libnvinfer-bin (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package libnvinfer-doc.
# Preparing to unpack .../libnvinfer-doc_7.0.0-1+cuda10.0_all.deb ...
# Unpacking libnvinfer-doc (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package libnvinfer-samples.
# Preparing to unpack .../libnvinfer-samples_7.0.0-1+cuda10.0_all.deb ...
# Unpacking libnvinfer-samples (7.0.0-1+cuda10.0) ...
# Selecting previously unselected package tensorrt.
# Preparing to unpack .../tensorrt_7.0.0.11-1+cuda10.0_amd64.deb ...
# Unpacking tensorrt (7.0.0.11-1+cuda10.0) ...
# Setting up libnvinfer-doc (7.0.0-1+cuda10.0) ...
# Setting up libnvinfer-bin (7.0.0-1+cuda10.0) ...
# Setting up libnvinfer-samples (7.0.0-1+cuda10.0) ...
# Setting up tensorrt (7.0.0.11-1+cuda10.0) ...
# W: Target Packages (Packages) is configured multiple times in /etc/apt/sources.list.d/nvidia-machine-learning.list:1 and /etc/apt/sources.list.d/nvidia-ml.list:1

# %% [markdown]
# # 验证是否安装成功

# %%
# !dpkg -l | grep TensorRT
# Out:
# ii  libnvinfer-bin                                               7.0.0-1+cuda10.0                      amd64        TensorRT binaries
# hi  libnvinfer-dev                                               7.0.0-1+cuda10.0                      amd64        TensorRT development libraries and headers
# ii  libnvinfer-doc                                               7.0.0-1+cuda10.0                      all          TensorRT documentation
# hi  libnvinfer-plugin-dev                                        7.0.0-1+cuda10.0                      amd64        TensorRT plugin libraries
# hi  libnvinfer-plugin7                                           7.0.0-1+cuda10.0                      amd64        TensorRT plugin libraries
# ii  libnvinfer-samples                                           7.0.0-1+cuda10.0                      all          TensorRT samples
# hi  libnvinfer7                                                  7.0.0-1+cuda10.0                      amd64        TensorRT runtime libraries
# hi  libnvonnxparsers-dev                                         7.0.0-1+cuda10.0                      amd64        TensorRT ONNX libraries
# hi  libnvonnxparsers7                                            7.0.0-1+cuda10.0                      amd64        TensorRT ONNX libraries
# hi  libnvparsers-dev                                             7.0.0-1+cuda10.0                      amd64        TensorRT parsers libraries
# hi  libnvparsers7                                                7.0.0-1+cuda10.0                      amd64        TensorRT parsers libraries
# hi  python-libnvinfer                                            7.0.0-1+cuda10.0                      amd64        Python bindings for TensorRT
# hi  python3-libnvinfer                                           7.0.0-1+cuda10.0                      amd64        Python 3 bindings for TensorRT
# ii  tensorrt                                                     7.0.0.11-1+cuda10.0                   amd64        Meta package of TensorRT

# %% [markdown]
# # 开始测试，先看看例子能不能运行

# %%
# !python uff_ssd/detect_objects.py
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/graphsurgeon/_utils.py:2: The name tf.NodeDef is deprecated. Please use tf.compat.v1.NodeDef instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/graphsurgeon/DynamicGraph.py:4: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# Traceback (most recent call last):
#   File "uff_ssd/detect_objects.py", line 60, in <module>
#     import utils.inference as inference_utils # TRT/TF inference wrappers
#   File "/content/gdrive/My Drive/Colab Notebooks/TensorRT Colab Test/uff_ssd/utils/inference.py", line 61, in <module>
#     import utils.engine as engine_utils # TRT Engine creation/save/load utils
#   File "/content/gdrive/My Drive/Colab Notebooks/TensorRT Colab Test/uff_ssd/utils/engine.py", line 68, in <module>
#     from common import HostDeviceMem
# ImportError: cannot import name 'HostDeviceMem'

# %% [markdown]
# # 解决ModuleNotFoundError: No module named 'pycuda'

# %%
# !pip install pycuda
# Out:
# Collecting pycuda
#   Downloading https://files.pythonhosted.org/packages/46/61/47d3235a4c13eec5a5f03594ddb268f4858734e02980afbcd806e6242fa5/pycuda-2020.1.tar.gz (1.6MB)
#      |████████████████████████████████| 1.6MB 9.2MB/s
# Collecting pytools>=2011.2
#   Downloading https://files.pythonhosted.org/packages/73/d5/989a1d2bba90f5c085e4929a4b703bbd8cc6b4a4218f1671fadab2abe966/pytools-2020.4.tar.gz (67kB)
#      |████████████████████████████████| 71kB 9.7MB/s
# Requirement already satisfied: decorator>=3.2.0 in /usr/local/lib/python3.6/dist-packages (from pycuda) (4.4.2)
# Collecting appdirs>=1.4.0
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Collecting mako
#   Downloading https://files.pythonhosted.org/packages/a6/37/0e706200d22172eb8fa17d68a7ae22dec7631a0a92266634fb518a88a5b2/Mako-1.1.3-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 10.7MB/s
# Requirement already satisfied: six>=1.8.0 in /usr/local/lib/python3.6/dist-packages (from pytools>=2011.2->pycuda) (1.15.0)
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from pytools>=2011.2->pycuda) (1.18.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from mako->pycuda) (1.1.1)
# Building wheels for collected packages: pycuda, pytools
#   Building wheel for pycuda (setup.py) ... done
#   Created wheel for pycuda: filename=pycuda-2020.1-cp36-cp36m-linux_x86_64.whl size=620932 sha256=4a59b2181a9d47ede110d7b297c824d8ffcfe81f9887257084d3e8e78362691a
#   Stored in directory: /root/.cache/pip/wheels/8f/78/d1/5bb826f81d9d490297a348d818ff3ee6dd6f2075b06dde6ea0
#   Building wheel for pytools (setup.py) ... done
#   Created wheel for pytools: filename=pytools-2020.4-py2.py3-none-any.whl size=67175 sha256=f2b945c811d19aa8f73f293b4e8c164b766115fb4131c254c7b7d967afb76f99
#   Stored in directory: /root/.cache/pip/wheels/5e/20/0b/fac51840734b2587ecc239a62522b164c374e929e2c9be66c5
# Successfully built pycuda pytools
# Installing collected packages: appdirs, pytools, mako, pycuda
# Successfully installed appdirs-1.4.4 mako-1.1.3 pycuda-2020.1 pytools-2020.4

# %% [markdown]
# # 查看python版本

# %%
# !python

# %% [markdown]
# # 解决ModuleNotFoundError: No module named 'graphsurgeon'

# %%
# !pip install graphsurgeon-0.4.1-py2.py3-none-any.whl
# Out:
# Processing ./graphsurgeon-0.4.1-py2.py3-none-any.whl
# Installing collected packages: graphsurgeon
# Successfully installed graphsurgeon-0.4.1

# %% [markdown]
# # 解决ImportError: cannot import name 'uff'

# %%
# !pip install uff-0.6.5-py2.py3-none-any.whl
# Out:
# Processing ./uff-0.6.5-py2.py3-none-any.whl
# Requirement already satisfied: protobuf>=3.3.0 in /usr/local/lib/python3.6/dist-packages (from uff==0.6.5) (3.12.4)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from uff==0.6.5) (1.18.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.3.0->uff==0.6.5) (50.3.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.3.0->uff==0.6.5) (1.15.0)
# Installing collected packages: uff
# Successfully installed uff-0.6.5

# %% [markdown]
# # 解决ImportError: cannot import name 'NodeDef'

# %%
# !pip uninstall tensorflow
# Out:
# Uninstalling tensorflow-2.3.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.3.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/_api/v2/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/compiler/mlir/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/compiler/tf2tensorrt/_pywrap_py_utils.so
#     /usr/local/lib/python3.6/dist-packages/tensorflow/compiler/tf2xla/tf2xla_pb2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/core/kernels/libtfkernel_sobol_op.so
#     /usr/local/lib/python3.6/dist-packages/tensorflow/core/profiler/profiler_options_pb2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/core/profiler/profiler_service_monitor_result_pb2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/core/profiler/protobuf/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/core/protobuf/bfc_memory_map_pb2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/core/protobuf/debug_event_pb2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/core/protobuf/device_filters_pb2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/core/protobuf/error_codes_pb2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/core/protobuf/remote_tensor_handle_pb2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/Eigen
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/IterativeLinearSolvers
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/MetisSupport
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/Sparse
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/SparseCholesky
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/SparseLU
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/src/Core/arch/AVX512/TypeCasting.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/src/Core/arch/AltiVec/MatrixProduct.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/src/Core/arch/Default/BFloat16.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/src/Core/arch/Default/GenericPacketMathFunctionsFwd.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/src/Core/arch/Default/Half.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/src/Core/arch/Default/TypeCasting.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/src/Core/arch/SYCL/SyclMemoryModel.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/src/OrderingMethods/Amd.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/src/SparseCholesky/SimplicialCholesky.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/Eigen/src/SparseCholesky/SimplicialCholesky_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/base/internal/errno_saver.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/base/internal/exponential_biased.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/base/internal/thread_annotations.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/base/options.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/container/internal/node_hash_policy.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/container/node_hash_map.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/container/node_hash_set.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/config.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/declare.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/flag.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/internal/commandlineflag.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/internal/flag.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/internal/path_util.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/internal/program_name.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/internal/registry.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/internal/type_erased.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/marshalling.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/flags/usage_config.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/absl/strings/internal/escaping.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/astunparse_archive/LICENSE
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/LICENSE
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/allocator.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/array_list.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/array_list.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/assert.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/atomics.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/atomics.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/atomics_fallback.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/atomics_gnu.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/atomics_gnu_old.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/atomics_msvc.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/byte_buf.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/byte_order.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/byte_order.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/clock.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/clock.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/command_line_parser.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/common.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/condition_variable.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/config.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/date_time.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/device_random.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/encoding.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/encoding.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/environment.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/error.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/error.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/exports.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/hash_table.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/linked_list.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/linked_list.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/log_channel.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/log_formatter.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/log_writer.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/logging.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/lru_cache.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/macros.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/math.cbmc.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/math.fallback.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/math.gcc_overflow.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/math.gcc_x64_asm.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/math.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/math.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/math.msvc.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/mutex.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/posix/common.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/predicates.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/priority_queue.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/private/array_list.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/private/byte_buf.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/private/hash_table_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/private/lookup3.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/process.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/ring_buffer.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/ring_buffer.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/rw_lock.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/stdbool.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/stdint.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/string.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/string.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/system_info.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/task_scheduler.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/thread.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/time.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/uuid.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/zero.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/common/zero.inl
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/testing/aws_test_allocators.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-common/include/aws/testing/aws_test_harness.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-event-stream/LICENSE
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-event-stream/include/aws/event-stream/event_stream.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-c-event-stream/include/aws/event-stream/event_stream_exports.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-checksums/LICENSE
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-checksums/include/aws/checksums/crc.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-checksums/include/aws/checksums/crc_jni.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-checksums/include/aws/checksums/exports.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-checksums/include/aws/checksums/private/cpuid.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws-checksums/include/aws/checksums/private/crc_priv.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/auth/AWSCredentials.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/auth/STSCredentialsProvider.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/client/SpecifiedRetryableErrorsRetryStrategy.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/monitoring/CoreMetrics.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/monitoring/DefaultMonitoring.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/monitoring/HttpClientMetrics.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/monitoring/MonitoringFactory.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/monitoring/MonitoringInterface.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/monitoring/MonitoringManager.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/net/Net.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/net/SimpleUDP.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/ARN.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/Cache.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/ConcurrentCache.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/event/EventDecoderStream.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/event/EventEncoderStream.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/event/EventHeader.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/event/EventMessage.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/event/EventStream.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/event/EventStreamBuf.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/event/EventStreamDecoder.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/event/EventStreamEncoder.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/event/EventStreamErrors.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/event/EventStreamHandler.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-core/include/aws/core/utils/stream/ConcurrentStreamBuf.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/S3ARN.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/DefaultRetention.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/DeleteMarkerReplication.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/DeleteMarkerReplicationStatus.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/DeletePublicAccessBlockRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ExistingObjectReplication.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ExistingObjectReplicationStatus.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/GetBucketPolicyStatusRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/GetBucketPolicyStatusResult.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/GetObjectLegalHoldRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/GetObjectLegalHoldResult.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/GetObjectLockConfigurationRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/GetObjectLockConfigurationResult.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/GetObjectRetentionRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/GetObjectRetentionResult.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/GetPublicAccessBlockRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/GetPublicAccessBlockResult.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/Metrics.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/MetricsStatus.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ObjectLockConfiguration.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ObjectLockEnabled.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ObjectLockLegalHold.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ObjectLockLegalHoldStatus.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ObjectLockMode.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ObjectLockRetention.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ObjectLockRetentionMode.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ObjectLockRule.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ParquetInput.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/PolicyStatus.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/Progress.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ProgressEvent.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/PublicAccessBlockConfiguration.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/PutObjectLegalHoldRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/PutObjectLegalHoldResult.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/PutObjectLockConfigurationRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/PutObjectLockConfigurationResult.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/PutObjectRetentionRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/PutObjectRetentionResult.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/PutPublicAccessBlockRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/RecordsEvent.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ReplicationRuleAndOperator.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ReplicationRuleFilter.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ReplicationTime.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ReplicationTimeStatus.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ReplicationTimeValue.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/RequestProgress.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/ScanRange.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/SelectObjectContentHandler.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/SelectObjectContentRequest.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/Stats.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-s3/include/aws/s3/model/StatsEvent.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-transfer/include/aws/transfer/TransferHandle.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-transfer/include/aws/transfer/TransferManager.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/aws/aws-cpp-sdk-transfer/include/aws/transfer/Transfer_EXPORTS.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/crypto/cpu-arm-linux.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/crypto/fipsmodule/md5/internal.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/crypto/fipsmodule/modes/gcm_nohw.c
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/crypto/fipsmodule/sha/internal.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/crypto/hrss/internal.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/crypto/x509v3/internal.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/include/openssl/hrss.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/include/openssl/siphash.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/third_party/fiat/curve25519_32.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/third_party/fiat/curve25519_64.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/third_party/fiat/p256_32.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/boringssl/src/third_party/fiat/p256_64.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/clog/LICENSE
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/LICENSE
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/alarm.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/channel.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/client_context.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/completion_queue.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/create_channel.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/create_channel_posix.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/ext/health_check_service_server_builder_option.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/generic/async_generic_service.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/generic/generic_stub.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/grpc++.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/health_check_service_interface.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/call.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/channel_argument_option.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/client_unary_call.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/async_stream.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/async_unary_call.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/byte_buffer.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/call.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/call_hook.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/channel_interface.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/client_context.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/client_unary_call.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/completion_queue.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/completion_queue_tag.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/config.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/config_protobuf.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/core_codegen.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/core_codegen_interface.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/create_auth_context.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/grpc_library.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/metadata_map.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/method_handler_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/proto_utils.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/rpc_method.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/rpc_service_method.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/security/auth_context.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/serialization_traits.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/server_context.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/server_interface.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/service_type.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/slice.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/status.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/status_code_enum.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/string_ref.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/stub_options.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/sync_stream.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/codegen/time.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/grpc_library.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/method_handler_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/rpc_method.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/rpc_service_method.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/serialization_traits.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/server_builder_option.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/server_builder_plugin.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/server_initializer.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/service_type.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/sync_cxx11.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/impl/sync_no_cxx11.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/resource_quota.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/security/auth_context.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/security/auth_metadata_processor.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/security/credentials.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/security/server_credentials.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/server.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/server_builder.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/server_context.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/server_posix.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/async_stream.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/async_unary_call.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/byte_buffer.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/channel_arguments.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/config.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/slice.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/status.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/status_code_enum.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/string_ref.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/stub_options.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/sync_stream.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc++/support/time.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/byte_buffer.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/byte_buffer_reader.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/census.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/compression.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/fork.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/grpc.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/grpc_posix.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/grpc_security.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/grpc_security_constants.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/atm.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/atm_gcc_atomic.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/atm_gcc_sync.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/atm_windows.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/byte_buffer.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/byte_buffer_reader.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/compression_types.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/connectivity_state.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/fork.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/gpr_slice.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/gpr_types.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/grpc_types.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/log.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/port_platform.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/propagation_bits.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/slice.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/status.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/sync.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/sync_custom.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/sync_generic.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/sync_posix.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/impl/codegen/sync_windows.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/load_reporting.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/slice.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/slice_buffer.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/status.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/alloc.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/atm.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/atm_gcc_atomic.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/atm_gcc_sync.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/atm_windows.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/cpu.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/log.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/log_windows.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/port_platform.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/string_util.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/sync.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/sync_custom.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/sync_generic.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/sync_posix.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/sync_windows.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/thd_id.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/time.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpc/support/workaround_list.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/alarm.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/alarm_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/channel.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/channel_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/client_context.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/completion_queue.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/completion_queue_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/create_channel.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/create_channel_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/create_channel_posix.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/create_channel_posix_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/ext/health_check_service_server_builder_option.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/generic/async_generic_service.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/generic/generic_stub.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/generic/generic_stub_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/grpcpp.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/health_check_service_interface.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/health_check_service_interface_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/call.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/channel_argument_option.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/client_unary_call.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/async_generic_service.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/async_stream.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/async_stream_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/async_unary_call.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/async_unary_call_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/byte_buffer.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/call.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/call_hook.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/call_op_set.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/call_op_set_interface.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/callback_common.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/channel_interface.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/client_callback.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/client_callback_impl.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/include/external/com_github_grpc_grpc/include/grpcpp/impl/codegen/client_context.h
# ...
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distributed_file_utils.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/mirrored_run.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/multi_process_lib.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/multi_process_runner.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/packed_distributed_variable.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/ps_values.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/sharded_variable.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/tpu_values.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/values_util.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/dlpack/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/backprop_util.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/benchmarks_test_base.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/cancellation.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/executor.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/forwardprop.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/forwardprop_util.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/memory_tests/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/feature_column/serialization.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/auto_control_deps_utils.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/combinations.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/gpu_util.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/memory_checker.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_callbacks.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/python_memory_checker.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/test_combinations.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/type_spec.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v1/keras/applications/efficientnet/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v1/keras/applications/imagenet_utils/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v1/keras/applications/resnet/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v1/keras/applications/resnet_v2/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v1/keras/callbacks/experimental/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v1/keras/layers/experimental/preprocessing/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v1/keras/premade/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v2/keras/applications/efficientnet/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v2/keras/applications/imagenet_utils/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v2/keras/applications/resnet/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v2/keras/applications/resnet_v2/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v2/keras/callbacks/experimental/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v2/keras/layers/experimental/preprocessing/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/_v2/keras/premade/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/keras/applications/efficientnet/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/keras/applications/imagenet_utils/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/keras/applications/resnet/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/keras/applications/resnet_v2/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/keras/callbacks/experimental/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/keras/layers/experimental/preprocessing/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/api/keras/premade/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/applications/efficientnet.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/applications/resnet.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/applications/resnet_v2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/combinations.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/distribute/keras_rnn_model_correctness_test.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/distribute/worker_training_state.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_preprocessing_layer.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_preprocessing_layer_v1.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/compile_utils.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/functional.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/keras_tensor.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/node.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_v1.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/feature_column/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/initializers/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/einsum_dense.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/legacy_rnn/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/ops/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/preprocessing/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/rnn_cell_wrapper_v2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/legacy_tf_layers/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/mixed_precision/experimental/device_compatibility_check.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/mixed_precision/experimental/get_layer_policy.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/mixed_precision/experimental/loss_scale.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizer_v2/legacy_learning_rate_decay.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/premade/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/preprocessing/dataset_utils.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/preprocessing/image_dataset.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/preprocessing/text_dataset.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/preprocessing/timeseries.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/protobuf/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/saved_model/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/saved_model_experimental.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/tests/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/all_utils.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/version_utils.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/kernel_tests/bias_op_base.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/kernel_tests/cudnn_deterministic_base.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/bincount_ops.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/control_flow_state.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/control_flow_v2_func_graphs.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/control_flow_v2_toggles.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/default_gradient.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_count_ops.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_debug_ops.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_rnn_ops.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_sendrecv_ops.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_special_math_ops.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/linalg/linear_operator_block_lower_triangular.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/linalg/linear_operator_permutation.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/linalg/linear_operator_tridiag.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/linalg/sparse/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/numpy_ops/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/op_selector.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/parsing_config.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/ragged/ragged_ops.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/ragged/row_partition.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn_cell_wrapper_impl.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn_grad.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/structured/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/analytics.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/device_context.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/remote_utils.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/internal/_pywrap_profiler.so
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/internal/_pywrap_traceme.so
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/profiler_client.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/profiler_v2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/trace.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/traceme.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/pywrap_mlir.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/pywrap_tfe.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/load_options.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/method_name_updater.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/save_options.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/tools/saved_model_aot_compile.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/tpu/api.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/tpu/client/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/tpu/feature_column_v2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/tpu/tensor_tracer_pb2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/tpu/tensor_tracer_report.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/tpu/tpu_embedding_v2.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/tpu/tpu_embedding_v2_utils.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/experimental/loss_scaling_gradient_tape.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/py_checkpoint_reader.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/quantize_training.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saving/checkpoint_options.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saving/saveable_hook.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/types/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/module_wrapper.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/object_identity.py
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/CMakeLists.txt
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/tf2xla/xla_compiled_cpu_function.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/xla/cpu_function_runtime.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/xla/executable_run_options.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/xla/service/cpu/runtime_fp16.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/xla/service/cpu/runtime_key_value_sort.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/xla/service/cpu/runtime_pow.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/xla/service/cpu/runtime_single_threaded_conv2d.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/xla/service/cpu/runtime_single_threaded_fft.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/compiler/xla/service/cpu/runtime_single_threaded_matmul.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/kernels/eigen_contraction_kernel.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/cord.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/ctstring.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/ctstring_internal.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/default/cord.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/default/dynamic_annotations.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/default/env_time.cc
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/default/integral_types.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/dynamic_annotations.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/env_time.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/macros.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/platform.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/tstring.h
#     /usr/local/lib/python3.6/dist-packages/tensorflow/xla_aot_runtime_src/tensorflow/core/platform/types.h
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.3.0

# %% [markdown]
# # 安装1.14.0 tensorflow

# %%
# !pip install tensorflow-gpu==1.14.0
# Out:
# Collecting tensorflow-gpu==1.14.0
#   Using cached https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.0.8)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (3.12.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.35.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.18.5)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.3.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.32.0)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.14.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.14.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.12.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.8.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.2.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.10.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14.0) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.14.0) (50.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.2.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.14.0

# %% [markdown]
# # 解决ModuleNotFoundError: No module named 'common'

# %% [markdown]
# *将common文件夹load进来即可*

# %% [markdown]
# # 解压压缩包

# %%
# !tar zxvf TensorRT-7.0.0.11.Ubuntu-18.04.x86_64-gnu.cuda-10.0.cudnn7.6.tar.gz
# Out:
# TensorRT-7.0.0.11/
# TensorRT-7.0.0.11/bin
# TensorRT-7.0.0.11/lib
# TensorRT-7.0.0.11/targets/
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/bin/
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/bin/trtexec
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/bin/giexec
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvcaffe_parser.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvcaffe_parser.so.7.0.0
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvcaffe_parser.so.7
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvcaffe_parser.so
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvparsers_static.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvparsers.so.7.0.0
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libprotobuf-lite.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libprotobuf.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvparsers.so.7
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvparsers.so
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvinfer_static.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvinfer.so.7.0.0
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvinfer.so.7
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvinfer.so
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvinfer_plugin_static.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvinfer_plugin.so.7.0.0
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvinfer_plugin.so.7
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvinfer_plugin.so
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvonnxparser.so.7.0.0
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvonnxparser.so.7
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvonnxparser.so
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libnvonnxparser_static.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/stubs/
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/stubs/libnvinfer.so
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/stubs/libnvparsers.so
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/stubs/libnvinfer_plugin.so
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/stubs/libnvonnxparser.so
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/stubs/libnvrtc_static.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libmyelin.so
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libmyelin.so.1
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libmyelin.so.1.0.0
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libmyelin_compiler_static.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libmyelin_executor_static.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libmyelin_pattern_library_static.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libmyelin_pattern_runtime_static.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/lib/libonnx_proto.a
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/include
# TensorRT-7.0.0.11/targets/x86_64-linux-gnu/samples
# TensorRT-7.0.0.11/samples/
# TensorRT-7.0.0.11/samples/sampleCharRNN/
# TensorRT-7.0.0.11/samples/sampleCharRNN/Makefile
# TensorRT-7.0.0.11/samples/sampleCharRNN/README.md
# TensorRT-7.0.0.11/samples/sampleCharRNN/sampleCharRNN.cpp
# TensorRT-7.0.0.11/samples/Makefile
# TensorRT-7.0.0.11/samples/Makefile.config
# TensorRT-7.0.0.11/samples/sampleDynamicReshape/
# TensorRT-7.0.0.11/samples/sampleDynamicReshape/Makefile
# TensorRT-7.0.0.11/samples/sampleDynamicReshape/README.md
# TensorRT-7.0.0.11/samples/sampleDynamicReshape/sampleDynamicReshape.cpp
# TensorRT-7.0.0.11/samples/sampleFasterRCNN/
# TensorRT-7.0.0.11/samples/sampleFasterRCNN/Makefile
# TensorRT-7.0.0.11/samples/sampleFasterRCNN/README.md
# TensorRT-7.0.0.11/samples/sampleFasterRCNN/factoryFasterRCNN.h
# TensorRT-7.0.0.11/samples/sampleFasterRCNN/sampleFasterRCNN.cpp
# TensorRT-7.0.0.11/samples/sampleGoogleNet/
# TensorRT-7.0.0.11/samples/sampleGoogleNet/Makefile
# TensorRT-7.0.0.11/samples/sampleGoogleNet/README.md
# TensorRT-7.0.0.11/samples/sampleGoogleNet/sampleGoogleNet.cpp
# TensorRT-7.0.0.11/samples/sampleINT8/
# TensorRT-7.0.0.11/samples/sampleINT8/Makefile
# TensorRT-7.0.0.11/samples/sampleINT8/README.md
# TensorRT-7.0.0.11/samples/sampleINT8/int8_caffe.patch
# TensorRT-7.0.0.11/samples/sampleINT8/sampleINT8.cpp
# TensorRT-7.0.0.11/samples/sampleINT8API/
# TensorRT-7.0.0.11/samples/sampleINT8API/Makefile
# TensorRT-7.0.0.11/samples/sampleINT8API/README.md
# TensorRT-7.0.0.11/samples/sampleINT8API/sampleINT8API.cpp
# TensorRT-7.0.0.11/samples/sampleMLP/
# TensorRT-7.0.0.11/samples/sampleMLP/Makefile
# TensorRT-7.0.0.11/samples/sampleMLP/README.md
# TensorRT-7.0.0.11/samples/sampleMLP/convert_weights.py
# TensorRT-7.0.0.11/samples/sampleMLP/sampleMLP.cpp
# TensorRT-7.0.0.11/samples/sampleMLP/update_mlp.patch
# TensorRT-7.0.0.11/samples/sampleMNIST/
# TensorRT-7.0.0.11/samples/sampleMNIST/Makefile
# TensorRT-7.0.0.11/samples/sampleMNIST/README.md
# TensorRT-7.0.0.11/samples/sampleMNIST/sampleMNIST.cpp
# TensorRT-7.0.0.11/samples/sampleMNISTAPI/
# TensorRT-7.0.0.11/samples/sampleMNISTAPI/Makefile
# TensorRT-7.0.0.11/samples/sampleMNISTAPI/README.md
# TensorRT-7.0.0.11/samples/sampleMNISTAPI/sampleMNISTAPI.cpp
# TensorRT-7.0.0.11/samples/sampleMovieLens/
# TensorRT-7.0.0.11/samples/sampleMovieLens/Makefile
# TensorRT-7.0.0.11/samples/sampleMovieLens/README.md
# TensorRT-7.0.0.11/samples/sampleMovieLens/preprocess.py
# TensorRT-7.0.0.11/samples/sampleMovieLens/sampleMovieLens.cpp
# TensorRT-7.0.0.11/samples/sampleMovieLens/sampleMovieLensTraining.patch
# TensorRT-7.0.0.11/samples/sampleNMT/
# TensorRT-7.0.0.11/samples/sampleNMT/Makefile
# TensorRT-7.0.0.11/samples/sampleNMT/README.md
# TensorRT-7.0.0.11/samples/sampleNMT/chptToBin.py
# TensorRT-7.0.0.11/samples/sampleNMT/component.h
# TensorRT-7.0.0.11/samples/sampleNMT/cudaError.h
# TensorRT-7.0.0.11/samples/sampleNMT/data/
# TensorRT-7.0.0.11/samples/sampleNMT/data/benchmarkWriter.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/data/benchmarkWriter.h
# TensorRT-7.0.0.11/samples/sampleNMT/data/bleuScoreWriter.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/data/bleuScoreWriter.h
# TensorRT-7.0.0.11/samples/sampleNMT/data/dataReader.h
# TensorRT-7.0.0.11/samples/sampleNMT/data/dataWriter.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/data/dataWriter.h
# TensorRT-7.0.0.11/samples/sampleNMT/data/limitedSamplesDataReader.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/data/limitedSamplesDataReader.h
# TensorRT-7.0.0.11/samples/sampleNMT/data/sequenceProperties.h
# TensorRT-7.0.0.11/samples/sampleNMT/data/textReader.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/data/textReader.h
# TensorRT-7.0.0.11/samples/sampleNMT/data/textWriter.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/data/textWriter.h
# TensorRT-7.0.0.11/samples/sampleNMT/data/vocabulary.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/data/vocabulary.h
# TensorRT-7.0.0.11/samples/sampleNMT/deviceBuffer.h
# TensorRT-7.0.0.11/samples/sampleNMT/get_newstest2015.sh
# TensorRT-7.0.0.11/samples/sampleNMT/model/
# TensorRT-7.0.0.11/samples/sampleNMT/model/alignment.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/attention.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/beamSearchPolicy.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/beamSearchPolicy.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/componentWeights.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/componentWeights.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/contextNMT.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/contextNMT.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/debugUtil.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/debugUtil.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/decoder.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/embedder.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/encoder.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/likelihood.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/likelihoodCombinationOperator.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/lstmDecoder.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/lstmDecoder.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/lstmEncoder.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/lstmEncoder.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/multiplicativeAlignment.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/multiplicativeAlignment.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/projection.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/slpAttention.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/slpAttention.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/slpEmbedder.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/slpEmbedder.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/slpProjection.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/slpProjection.h
# TensorRT-7.0.0.11/samples/sampleNMT/model/softmaxLikelihood.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/model/softmaxLikelihood.h
# TensorRT-7.0.0.11/samples/sampleNMT/pinnedHostBuffer.h
# TensorRT-7.0.0.11/samples/sampleNMT/sampleNMT.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/trtUtil.cpp
# TensorRT-7.0.0.11/samples/sampleNMT/trtUtil.h
# TensorRT-7.0.0.11/samples/sampleOnnxMNIST/
# TensorRT-7.0.0.11/samples/sampleOnnxMNIST/Makefile
# TensorRT-7.0.0.11/samples/sampleOnnxMNIST/README.md
# TensorRT-7.0.0.11/samples/sampleOnnxMNIST/sampleOnnxMNIST.cpp
# TensorRT-7.0.0.11/samples/samplePlugin/
# TensorRT-7.0.0.11/samples/samplePlugin/Makefile
# TensorRT-7.0.0.11/samples/samplePlugin/README.md
# TensorRT-7.0.0.11/samples/samplePlugin/fcPlugin.h
# TensorRT-7.0.0.11/samples/samplePlugin/fp16.h
# TensorRT-7.0.0.11/samples/samplePlugin/samplePlugin.cpp
# TensorRT-7.0.0.11/samples/sampleSSD/
# TensorRT-7.0.0.11/samples/sampleSSD/Makefile
# TensorRT-7.0.0.11/samples/sampleSSD/PrepareINT8CalibrationBatches.sh
# TensorRT-7.0.0.11/samples/sampleSSD/README.md
# TensorRT-7.0.0.11/samples/sampleSSD/batchPrepare.py
# TensorRT-7.0.0.11/samples/sampleSSD/requirements.txt
# TensorRT-7.0.0.11/samples/sampleSSD/sampleSSD.cpp
# TensorRT-7.0.0.11/samples/sampleUffFasterRCNN/
# TensorRT-7.0.0.11/samples/sampleUffFasterRCNN/Makefile
# TensorRT-7.0.0.11/samples/sampleUffFasterRCNN/README.md
# TensorRT-7.0.0.11/samples/sampleUffFasterRCNN/config.py
# TensorRT-7.0.0.11/samples/sampleUffFasterRCNN/download_model.sh
# TensorRT-7.0.0.11/samples/sampleUffFasterRCNN/fix_softmax.patch
# TensorRT-7.0.0.11/samples/sampleUffFasterRCNN/frcnnUtils.h
# TensorRT-7.0.0.11/samples/sampleUffFasterRCNN/sampleUffFasterRCNN.cpp
# TensorRT-7.0.0.11/samples/sampleUffMaskRCNN/
# TensorRT-7.0.0.11/samples/sampleUffMaskRCNN/Makefile
# TensorRT-7.0.0.11/samples/sampleUffMaskRCNN/README.md
# TensorRT-7.0.0.11/samples/sampleUffMaskRCNN/converted/
# TensorRT-7.0.0.11/samples/sampleUffMaskRCNN/converted/0001-Update-the-Mask_RCNN-model-from-NHWC-to-NCHW.patch
# TensorRT-7.0.0.11/samples/sampleUffMaskRCNN/converted/config.py
# TensorRT-7.0.0.11/samples/sampleUffMaskRCNN/converted/mrcnn_to_trt_single.py
# TensorRT-7.0.0.11/samples/sampleUffMaskRCNN/converted/requirements.txt
# TensorRT-7.0.0.11/samples/sampleUffMaskRCNN/mrcnn_config.h
# TensorRT-7.0.0.11/samples/sampleUffMaskRCNN/sampleUffMaskRCNN.cpp
# TensorRT-7.0.0.11/samples/sampleUffMNIST/
# TensorRT-7.0.0.11/samples/sampleUffMNIST/Makefile
# TensorRT-7.0.0.11/samples/sampleUffMNIST/README.md
# TensorRT-7.0.0.11/samples/sampleUffMNIST/sampleUffMNIST.cpp
# TensorRT-7.0.0.11/samples/sampleUffSSD/
# TensorRT-7.0.0.11/samples/sampleUffSSD/Makefile
# TensorRT-7.0.0.11/samples/sampleUffSSD/README.md
# TensorRT-7.0.0.11/samples/sampleUffSSD/config.py
# TensorRT-7.0.0.11/samples/sampleUffSSD/sampleUffSSD.cpp
# TensorRT-7.0.0.11/samples/trtexec/
# TensorRT-7.0.0.11/samples/trtexec/Makefile
# TensorRT-7.0.0.11/samples/trtexec/README.md
# TensorRT-7.0.0.11/samples/trtexec/giexec
# TensorRT-7.0.0.11/samples/trtexec/prn_utils.py
# TensorRT-7.0.0.11/samples/trtexec/profiler.py
# TensorRT-7.0.0.11/samples/trtexec/tracer.py
# TensorRT-7.0.0.11/samples/trtexec/trtexec.cpp
# TensorRT-7.0.0.11/samples/sampleReformatFreeIO/
# TensorRT-7.0.0.11/samples/sampleReformatFreeIO/Makefile
# TensorRT-7.0.0.11/samples/sampleReformatFreeIO/README.md
# TensorRT-7.0.0.11/samples/sampleReformatFreeIO/sampleReformatFreeIO.cpp
# TensorRT-7.0.0.11/samples/sampleUffPluginV2Ext/
# TensorRT-7.0.0.11/samples/sampleUffPluginV2Ext/Makefile
# TensorRT-7.0.0.11/samples/sampleUffPluginV2Ext/README.md
# TensorRT-7.0.0.11/samples/sampleUffPluginV2Ext/sampleUffPluginV2Ext.cpp
# TensorRT-7.0.0.11/samples/sampleMovieLensMPS/
# TensorRT-7.0.0.11/samples/sampleMovieLensMPS/Makefile
# TensorRT-7.0.0.11/samples/sampleMovieLensMPS/README.md
# TensorRT-7.0.0.11/samples/sampleMovieLensMPS/preprocess.py
# TensorRT-7.0.0.11/samples/sampleMovieLensMPS/sampleMovieLensMPS.cpp
# TensorRT-7.0.0.11/samples/sampleMovieLensMPS/sampleMovieLensTraining.patch
# TensorRT-7.0.0.11/samples/common/
# TensorRT-7.0.0.11/samples/common/BatchStream.h
# TensorRT-7.0.0.11/samples/common/EntropyCalibrator.h
# TensorRT-7.0.0.11/samples/common/ErrorRecorder.h
# TensorRT-7.0.0.11/samples/common/argsParser.h
# TensorRT-7.0.0.11/samples/common/buffers.h
# TensorRT-7.0.0.11/samples/common/common.h
# TensorRT-7.0.0.11/samples/common/dumpTFWts.py
# TensorRT-7.0.0.11/samples/common/getOptions.cpp
# TensorRT-7.0.0.11/samples/common/getOptions.h
# TensorRT-7.0.0.11/samples/common/half.h
# TensorRT-7.0.0.11/samples/common/logger.cpp
# TensorRT-7.0.0.11/samples/common/logger.h
# TensorRT-7.0.0.11/samples/common/logging.h
# TensorRT-7.0.0.11/samples/common/parserOnnxConfig.h
# TensorRT-7.0.0.11/samples/common/sampleConfig.h
# TensorRT-7.0.0.11/samples/common/sampleDevice.h
# TensorRT-7.0.0.11/samples/common/sampleEngines.cpp
# TensorRT-7.0.0.11/samples/common/sampleEngines.h
# TensorRT-7.0.0.11/samples/common/sampleInference.cpp
# TensorRT-7.0.0.11/samples/common/sampleInference.h
# TensorRT-7.0.0.11/samples/common/sampleOptions.cpp
# TensorRT-7.0.0.11/samples/common/sampleOptions.h
# TensorRT-7.0.0.11/samples/common/sampleReporting.cpp
# TensorRT-7.0.0.11/samples/common/sampleReporting.h
# TensorRT-7.0.0.11/samples/common/sampleUtils.h
# TensorRT-7.0.0.11/samples/python/
# TensorRT-7.0.0.11/samples/python/engine_refit_mnist/
# TensorRT-7.0.0.11/samples/python/engine_refit_mnist/README.md
# TensorRT-7.0.0.11/samples/python/engine_refit_mnist/model.py
# TensorRT-7.0.0.11/samples/python/engine_refit_mnist/requirements.txt
# TensorRT-7.0.0.11/samples/python/engine_refit_mnist/sample.py
# TensorRT-7.0.0.11/samples/python/introductory_parser_samples/
# TensorRT-7.0.0.11/samples/python/introductory_parser_samples/README.md
# TensorRT-7.0.0.11/samples/python/introductory_parser_samples/caffe_resnet50.py
# TensorRT-7.0.0.11/samples/python/introductory_parser_samples/onnx_resnet50.py
# TensorRT-7.0.0.11/samples/python/introductory_parser_samples/requirements.txt
# TensorRT-7.0.0.11/samples/python/introductory_parser_samples/uff_resnet50.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/
# TensorRT-7.0.0.11/samples/python/uff_ssd/README.md
# TensorRT-7.0.0.11/samples/python/uff_ssd/detect_objects.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/requirements.txt
# TensorRT-7.0.0.11/samples/python/uff_ssd/voc_evaluation.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/images/
# TensorRT-7.0.0.11/samples/python/uff_ssd/images/image1.jpg
# TensorRT-7.0.0.11/samples/python/uff_ssd/images/image2.jpg
# TensorRT-7.0.0.11/samples/python/uff_ssd/images/image_details.txt
# TensorRT-7.0.0.11/samples/python/uff_ssd/utils/
# TensorRT-7.0.0.11/samples/python/uff_ssd/utils/__init__.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/utils/boxes.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/utils/coco.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/utils/engine.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/utils/inference.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/utils/mAP.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/utils/model.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/utils/paths.py
# TensorRT-7.0.0.11/samples/python/uff_ssd/utils/voc.py
# TensorRT-7.0.0.11/samples/python/fc_plugin_caffe_mnist/
# TensorRT-7.0.0.11/samples/python/fc_plugin_caffe_mnist/CMakeLists.txt
# TensorRT-7.0.0.11/samples/python/fc_plugin_caffe_mnist/README.md
# TensorRT-7.0.0.11/samples/python/fc_plugin_caffe_mnist/__init__.py
# TensorRT-7.0.0.11/samples/python/fc_plugin_caffe_mnist/requirements.txt
# TensorRT-7.0.0.11/samples/python/fc_plugin_caffe_mnist/sample.py
# TensorRT-7.0.0.11/samples/python/fc_plugin_caffe_mnist/plugin/
# TensorRT-7.0.0.11/samples/python/fc_plugin_caffe_mnist/plugin/FullyConnected.cpp
# TensorRT-7.0.0.11/samples/python/fc_plugin_caffe_mnist/plugin/FullyConnected.h
# TensorRT-7.0.0.11/samples/python/network_api_pytorch_mnist/
# TensorRT-7.0.0.11/samples/python/network_api_pytorch_mnist/README.md
# TensorRT-7.0.0.11/samples/python/network_api_pytorch_mnist/model.py
# TensorRT-7.0.0.11/samples/python/network_api_pytorch_mnist/requirements.txt
# TensorRT-7.0.0.11/samples/python/network_api_pytorch_mnist/sample.py
# TensorRT-7.0.0.11/samples/python/common.py
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/CMakeLists.txt
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/README.md
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/__init__.py
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/lenet5.py
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/requirements.txt
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/sample.py
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/plugin/
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/plugin/clipKernel.cu
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/plugin/clipKernel.h
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/plugin/customClipPlugin.cpp
# TensorRT-7.0.0.11/samples/python/uff_custom_plugin/plugin/customClipPlugin.h
# TensorRT-7.0.0.11/samples/python/end_to_end_tensorflow_mnist/
# TensorRT-7.0.0.11/samples/python/end_to_end_tensorflow_mnist/README.md
# TensorRT-7.0.0.11/samples/python/end_to_end_tensorflow_mnist/model.py
# TensorRT-7.0.0.11/samples/python/end_to_end_tensorflow_mnist/requirements.txt
# TensorRT-7.0.0.11/samples/python/end_to_end_tensorflow_mnist/sample.py
# TensorRT-7.0.0.11/samples/python/int8_caffe_mnist/
# TensorRT-7.0.0.11/samples/python/int8_caffe_mnist/README.md
# TensorRT-7.0.0.11/samples/python/int8_caffe_mnist/calibrator.py
# TensorRT-7.0.0.11/samples/python/int8_caffe_mnist/requirements.txt
# TensorRT-7.0.0.11/samples/python/int8_caffe_mnist/sample.py
# TensorRT-7.0.0.11/samples/python/yolov3_onnx/
# TensorRT-7.0.0.11/samples/python/yolov3_onnx/README.md
# TensorRT-7.0.0.11/samples/python/yolov3_onnx/coco_labels.txt
# TensorRT-7.0.0.11/samples/python/yolov3_onnx/data_processing.py
# TensorRT-7.0.0.11/samples/python/yolov3_onnx/onnx_to_tensorrt.py
# TensorRT-7.0.0.11/samples/python/yolov3_onnx/requirements.txt
# TensorRT-7.0.0.11/samples/python/yolov3_onnx/yolov3_to_onnx.py
# TensorRT-7.0.0.11/include/
# TensorRT-7.0.0.11/include/NvCaffeParser.h
# TensorRT-7.0.0.11/include/NvInfer.h
# TensorRT-7.0.0.11/include/NvInferPlugin.h
# TensorRT-7.0.0.11/include/NvInferPluginUtils.h
# TensorRT-7.0.0.11/include/NvInferRuntime.h
# TensorRT-7.0.0.11/include/NvInferVersion.h
# TensorRT-7.0.0.11/include/NvOnnxConfig.h
# TensorRT-7.0.0.11/include/NvUffParser.h
# TensorRT-7.0.0.11/include/NvUtils.h
# TensorRT-7.0.0.11/include/NvInferRuntimeCommon.h
# TensorRT-7.0.0.11/include/NvOnnxParser.h
# TensorRT-7.0.0.11/data/
# TensorRT-7.0.0.11/data/char-rnn/
# TensorRT-7.0.0.11/data/char-rnn/model/
# TensorRT-7.0.0.11/data/char-rnn/model/checkpoint
# TensorRT-7.0.0.11/data/char-rnn/model/model-20080.data-00000-of-00001
# TensorRT-7.0.0.11/data/char-rnn/model/model-20080.index
# TensorRT-7.0.0.11/data/char-rnn/model/model-20080.meta
# TensorRT-7.0.0.11/data/char-rnn/char-rnn.wts
# TensorRT-7.0.0.11/data/mnist/
# TensorRT-7.0.0.11/data/mnist/mnist.onnx
# TensorRT-7.0.0.11/data/mnist/mnist.caffemodel
# TensorRT-7.0.0.11/data/mnist/mnist.prototxt
# TensorRT-7.0.0.11/data/mnist/mnist_lenet.caffemodel
# TensorRT-7.0.0.11/data/mnist/mnist_mean.binaryproto
# TensorRT-7.0.0.11/data/mnist/mnistapi.wts
# TensorRT-7.0.0.11/data/mnist/mnistgie.wts
# TensorRT-7.0.0.11/data/mnist/deploy.prototxt
# TensorRT-7.0.0.11/data/mnist/lenet5.uff
# TensorRT-7.0.0.11/data/mnist/lenet5.uff.txt
# TensorRT-7.0.0.11/data/mnist/lenet5_custom_pool.uff
# TensorRT-7.0.0.11/data/mnist/lenet5_custom_pool.uff.txt
# TensorRT-7.0.0.11/data/mnist/lenet5_mnist_frozen.pb
# TensorRT-7.0.0.11/data/mnist/README.md
# TensorRT-7.0.0.11/data/mnist/download_pgms.py
# TensorRT-7.0.0.11/data/mlp/
# TensorRT-7.0.0.11/data/mlp/sampleMLP.wts2
# TensorRT-7.0.0.11/data/movielens/
# TensorRT-7.0.0.11/data/movielens/movielens_ratings.txt
# TensorRT-7.0.0.11/data/movielens/sampleMovieLens.uff
# TensorRT-7.0.0.11/data/googlenet/
# TensorRT-7.0.0.11/data/googlenet/googlenet.caffemodel
# TensorRT-7.0.0.11/data/googlenet/googlenet.prototxt
# TensorRT-7.0.0.11/data/googlenet/README.md
# TensorRT-7.0.0.11/data/faster-rcnn/
# TensorRT-7.0.0.11/data/faster-rcnn/000456.ppm
# TensorRT-7.0.0.11/data/faster-rcnn/000542.ppm
# TensorRT-7.0.0.11/data/faster-rcnn/001150.ppm
# TensorRT-7.0.0.11/data/faster-rcnn/001763.ppm
# TensorRT-7.0.0.11/data/faster-rcnn/004545.ppm
# TensorRT-7.0.0.11/data/faster-rcnn/faster_rcnn_test_iplugin.prototxt
# TensorRT-7.0.0.11/data/resnet50/
# TensorRT-7.0.0.11/data/resnet50/ResNet50_fp32.caffemodel
# TensorRT-7.0.0.11/data/resnet50/binoculars.jpeg
# TensorRT-7.0.0.11/data/resnet50/class_labels.txt
# TensorRT-7.0.0.11/data/resnet50/readme.txt
# TensorRT-7.0.0.11/data/resnet50/reflex_camera.jpeg
# TensorRT-7.0.0.11/data/resnet50/tabby_tiger_cat.jpg
# TensorRT-7.0.0.11/data/resnet50/ResNet50.onnx
# TensorRT-7.0.0.11/data/resnet50/ResNet50_N2.prototxt
# TensorRT-7.0.0.11/data/resnet50/airliner.ppm
# TensorRT-7.0.0.11/data/resnet50/README.md
# TensorRT-7.0.0.11/data/resnet50/resnet50-infer-5.uff
# TensorRT-7.0.0.11/data/ssd/
# TensorRT-7.0.0.11/data/ssd/bus.ppm
# TensorRT-7.0.0.11/data/ssd/dog.ppm
# TensorRT-7.0.0.11/data/ssd/ssd_coco_labels.txt
# TensorRT-7.0.0.11/data/ssd/batches/
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration46.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration47.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration47.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration48.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration48.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration49.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration49.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration5.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration5.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration6.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration6.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration7.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration7.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration8.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration8.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration9.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration9.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration18.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration18.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration19.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration19.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration2.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration2.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration20.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration20.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration21.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration21.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration22.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration22.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration23.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration23.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration24.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration24.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration25.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration25.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration26.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration26.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration27.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration0.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration0.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration1.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration1.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration10.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration10.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration11.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration11.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration12.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration12.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration13.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration13.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration14.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration14.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration15.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration15.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration16.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration16.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration17.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration17.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration27.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration28.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration28.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration29.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration29.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration3.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration3.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration30.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration30.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration31.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration31.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration32.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration32.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration33.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration33.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration34.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration34.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration35.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration35.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration36.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration36.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration37.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration37.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration38.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration38.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration39.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration39.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration4.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration4.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration40.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration40.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration41.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration41.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration42.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration42.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration43.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration43.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration44.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration44.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration45.batch
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration45.list
# TensorRT-7.0.0.11/data/ssd/batches/batch_calibration46.batch
# TensorRT-7.0.0.11/data/int8_api/
# TensorRT-7.0.0.11/data/int8_api/airliner.ppm
# TensorRT-7.0.0.11/data/int8_api/reference_labels.txt
# TensorRT-7.0.0.11/data/int8_api/resnet50_per_tensor_dynamic_range.txt
# TensorRT-7.0.0.11/doc/
# TensorRT-7.0.0.11/doc/python/
# TensorRT-7.0.0.11/doc/python/coreConcepts.html
# TensorRT-7.0.0.11/doc/python/gettingStarted.html
# TensorRT-7.0.0.11/doc/python/graphsurgeon/
# TensorRT-7.0.0.11/doc/python/graphsurgeon/graphsurgeon.html
# TensorRT-7.0.0.11/doc/python/index.html
# TensorRT-7.0.0.11/doc/python/migrationGuide.html
# TensorRT-7.0.0.11/doc/python/genindex.html
# TensorRT-7.0.0.11/doc/python/search.html
# TensorRT-7.0.0.11/doc/python/_static/
# TensorRT-7.0.0.11/doc/python/_static/pygments.css
# TensorRT-7.0.0.11/doc/python/_static/ajax-loader.gif
# TensorRT-7.0.0.11/doc/python/_static/basic.css
# TensorRT-7.0.0.11/doc/python/_static/comment-bright.png
# TensorRT-7.0.0.11/doc/python/_static/comment-close.png
# TensorRT-7.0.0.11/doc/python/_static/comment.png
# TensorRT-7.0.0.11/doc/python/_static/doctools.js
# TensorRT-7.0.0.11/doc/python/_static/documentation_options.js
# TensorRT-7.0.0.11/doc/python/_static/down-pressed.png
# TensorRT-7.0.0.11/doc/python/_static/down.png
# TensorRT-7.0.0.11/doc/python/_static/file.png
# TensorRT-7.0.0.11/doc/python/_static/jquery-3.2.1.js
# TensorRT-7.0.0.11/doc/python/_static/jquery.js
# TensorRT-7.0.0.11/doc/python/_static/language_data.js
# TensorRT-7.0.0.11/doc/python/_static/minus.png
# TensorRT-7.0.0.11/doc/python/_static/plus.png
# TensorRT-7.0.0.11/doc/python/_static/searchtools.js
# TensorRT-7.0.0.11/doc/python/_static/underscore-1.3.1.js
# TensorRT-7.0.0.11/doc/python/_static/underscore.js
# TensorRT-7.0.0.11/doc/python/_static/up-pressed.png
# TensorRT-7.0.0.11/doc/python/_static/up.png
# TensorRT-7.0.0.11/doc/python/_static/websupport.js
# TensorRT-7.0.0.11/doc/python/_static/style.css
# TensorRT-7.0.0.11/doc/python/_static/nvlogo_white.png
# TensorRT-7.0.0.11/doc/python/_static/css/
# TensorRT-7.0.0.11/doc/python/_static/css/badge_only.css
# TensorRT-7.0.0.11/doc/python/_static/css/theme.css
# TensorRT-7.0.0.11/doc/python/_static/fonts/
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-bold.eot
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-bold.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-bold.woff
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-bold.woff2
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-bolditalic.eot
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-bolditalic.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-bolditalic.woff
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-bolditalic.woff2
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-italic.eot
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-italic.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-italic.woff
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-italic.woff2
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-regular.eot
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-regular.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-regular.woff
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato/lato-regular.woff2
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab/
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab/roboto-slab-v7-bold.eot
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab/roboto-slab-v7-bold.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab/roboto-slab-v7-bold.woff
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab/roboto-slab-v7-bold.woff2
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab/roboto-slab-v7-regular.eot
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab/roboto-slab-v7-regular.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab/roboto-slab-v7-regular.woff
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab/roboto-slab-v7-regular.woff2
# TensorRT-7.0.0.11/doc/python/_static/fonts/Inconsolata-Bold.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/Inconsolata-Regular.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/Inconsolata.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato-Bold.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/Lato-Regular.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab-Bold.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/RobotoSlab-Regular.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/fontawesome-webfont.eot
# TensorRT-7.0.0.11/doc/python/_static/fonts/fontawesome-webfont.svg
# TensorRT-7.0.0.11/doc/python/_static/fonts/fontawesome-webfont.ttf
# TensorRT-7.0.0.11/doc/python/_static/fonts/fontawesome-webfont.woff
# TensorRT-7.0.0.11/doc/python/_static/fonts/fontawesome-webfont.woff2
# TensorRT-7.0.0.11/doc/python/_static/img/
# TensorRT-7.0.0.11/doc/python/_static/img/nvlogo.svg
# TensorRT-7.0.0.11/doc/python/_static/img/nvlogo_white.png
# TensorRT-7.0.0.11/doc/python/_static/js/
# TensorRT-7.0.0.11/doc/python/_static/js/modernizr.min.js
# TensorRT-7.0.0.11/doc/python/_static/js/theme.js
# TensorRT-7.0.0.11/doc/python/.buildinfo
# TensorRT-7.0.0.11/doc/python/searchindex.js
# TensorRT-7.0.0.11/doc/python/objects.inv
# TensorRT-7.0.0.11/doc/python/infer/
# TensorRT-7.0.0.11/doc/python/infer/Graph/
# TensorRT-7.0.0.11/doc/python/infer/Graph/Network.html
# TensorRT-7.0.0.11/doc/python/infer/Graph/LayerBase.html
# TensorRT-7.0.0.11/doc/python/infer/Graph/Layers.html
# TensorRT-7.0.0.11/doc/python/infer/Graph/pyGraph.html
# TensorRT-7.0.0.11/doc/python/infer/Plugin/
# TensorRT-7.0.0.11/doc/python/infer/Plugin/IPlugin.html
# TensorRT-7.0.0.11/doc/python/infer/Plugin/IPluginCreator.html
# TensorRT-7.0.0.11/doc/python/infer/Plugin/IPluginExt.html
# TensorRT-7.0.0.11/doc/python/infer/Plugin/IPluginFactory.html
# TensorRT-7.0.0.11/doc/python/infer/Plugin/IPluginRegistry.html
# TensorRT-7.0.0.11/doc/python/infer/Plugin/IPluginV2.html
# TensorRT-7.0.0.11/doc/python/infer/Plugin/IPluginV2Ext.html
# TensorRT-7.0.0.11/doc/python/infer/Plugin/pyPlugin.html
# TensorRT-7.0.0.11/doc/python/infer/FoundationalTypes/
# TensorRT-7.0.0.11/doc/python/infer/FoundationalTypes/DataType.html
# TensorRT-7.0.0.11/doc/python/infer/FoundationalTypes/DimensionType.html
# TensorRT-7.0.0.11/doc/python/infer/FoundationalTypes/Dims.html
# TensorRT-7.0.0.11/doc/python/infer/FoundationalTypes/HostMemory.html
# TensorRT-7.0.0.11/doc/python/infer/FoundationalTypes/Weights.html
# TensorRT-7.0.0.11/doc/python/infer/FoundationalTypes/pyFoundationalTypes.html
# TensorRT-7.0.0.11/doc/python/infer/Int8/
# TensorRT-7.0.0.11/doc/python/infer/Int8/Calibrator.html
# TensorRT-7.0.0.11/doc/python/infer/Int8/EntropyCalibrator.html
# TensorRT-7.0.0.11/doc/python/infer/Int8/EntropyCalibrator2.html
# TensorRT-7.0.0.11/doc/python/infer/Int8/LegacyCalibrator.html
# TensorRT-7.0.0.11/doc/python/infer/Int8/MinMaxCalibrator.html
# TensorRT-7.0.0.11/doc/python/infer/Int8/pyInt8.html
# TensorRT-7.0.0.11/doc/python/infer/Core/
# TensorRT-7.0.0.11/doc/python/infer/Core/Builder.html
# TensorRT-7.0.0.11/doc/python/infer/Core/Engine.html
# TensorRT-7.0.0.11/doc/python/infer/Core/ExecutionContext.html
# TensorRT-7.0.0.11/doc/python/infer/Core/Logger.html
# TensorRT-7.0.0.11/doc/python/infer/Core/NetworkConfig.html
# TensorRT-7.0.0.11/doc/python/infer/Core/OptimizationProfile.html
# TensorRT-7.0.0.11/doc/python/infer/Core/Profiler.html
# TensorRT-7.0.0.11/doc/python/infer/Core/Refitter.html
# TensorRT-7.0.0.11/doc/python/infer/Core/Runtime.html
# TensorRT-7.0.0.11/doc/python/infer/Core/pyCore.html
# TensorRT-7.0.0.11/doc/python/parsers/
# TensorRT-7.0.0.11/doc/python/parsers/Uff/
# TensorRT-7.0.0.11/doc/python/parsers/Uff/Fields.html
# TensorRT-7.0.0.11/doc/python/parsers/Uff/Plugins.html
# TensorRT-7.0.0.11/doc/python/parsers/Uff/pyUff.html
# TensorRT-7.0.0.11/doc/python/parsers/Onnx/
# TensorRT-7.0.0.11/doc/python/parsers/Onnx/pyOnnx.html
# TensorRT-7.0.0.11/doc/python/parsers/Caffe/
# TensorRT-7.0.0.11/doc/python/parsers/Caffe/Plugins.html
# TensorRT-7.0.0.11/doc/python/parsers/Caffe/pyCaffe.html
# TensorRT-7.0.0.11/doc/python/uff/
# TensorRT-7.0.0.11/doc/python/uff/Operators.html
# TensorRT-7.0.0.11/doc/python/uff/uff.html
# TensorRT-7.0.0.11/doc/python/_sources/
# TensorRT-7.0.0.11/doc/python/_sources/parsers/
# TensorRT-7.0.0.11/doc/python/_sources/parsers/Caffe/
# TensorRT-7.0.0.11/doc/python/_sources/parsers/Caffe/Plugins.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/parsers/Caffe/pyCaffe.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/parsers/Uff/
# TensorRT-7.0.0.11/doc/python/_sources/parsers/Uff/Fields.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/parsers/Uff/Plugins.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/parsers/Uff/pyUff.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/parsers/Onnx/
# TensorRT-7.0.0.11/doc/python/_sources/parsers/Onnx/pyOnnx.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/Builder.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/Engine.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/ExecutionContext.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/Logger.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/NetworkConfig.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/OptimizationProfile.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/Profiler.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/Refitter.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/Runtime.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Core/pyCore.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Graph/
# TensorRT-7.0.0.11/doc/python/_sources/infer/Graph/LayerBase.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Graph/Layers.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Graph/Network.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Graph/pyGraph.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Plugin/
# TensorRT-7.0.0.11/doc/python/_sources/infer/Plugin/IPlugin.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Plugin/IPluginCreator.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Plugin/IPluginExt.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Plugin/IPluginFactory.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Plugin/IPluginRegistry.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Plugin/IPluginV2.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Plugin/IPluginV2Ext.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Plugin/pyPlugin.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/FoundationalTypes/
# TensorRT-7.0.0.11/doc/python/_sources/infer/FoundationalTypes/DataType.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/FoundationalTypes/DimensionType.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/FoundationalTypes/Dims.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/FoundationalTypes/HostMemory.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/FoundationalTypes/Weights.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/FoundationalTypes/pyFoundationalTypes.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Int8/
# TensorRT-7.0.0.11/doc/python/_sources/infer/Int8/Calibrator.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Int8/EntropyCalibrator.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Int8/EntropyCalibrator2.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Int8/LegacyCalibrator.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Int8/MinMaxCalibrator.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/infer/Int8/pyInt8.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/graphsurgeon/
# TensorRT-7.0.0.11/doc/python/_sources/graphsurgeon/graphsurgeon.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/coreConcepts.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/gettingStarted.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/index.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/migrationGuide.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/uff/
# TensorRT-7.0.0.11/doc/python/_sources/uff/Operators.rst.txt
# TensorRT-7.0.0.11/doc/python/_sources/uff/uff.rst.txt
# TensorRT-7.0.0.11/doc/cpp/
# TensorRT-7.0.0.11/doc/cpp/_nv_caffe_parser_8h_source.html
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_8h.html
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_8h.js
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_8h_source.html
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_plugin_8h.html
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_plugin_8h.js
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_plugin_8h_source.html
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_plugin_utils_8h_source.html
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_runtime_8h.html
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_runtime_8h.js
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_runtime_8h_source.html
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_runtime_common_8h.html
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_runtime_common_8h.js
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_runtime_common_8h_source.html
# TensorRT-7.0.0.11/doc/cpp/_nv_infer_version_8h_source.html
# TensorRT-7.0.0.11/doc/cpp/_nv_onnx_config_8h.html
# TensorRT-7.0.0.11/doc/cpp/_nv_onnx_config_8h.js
# TensorRT-7.0.0.11/doc/cpp/_nv_onnx_config_8h_source.html
# TensorRT-7.0.0.11/doc/cpp/_nv_uff_parser_8h_source.html
# TensorRT-7.0.0.11/doc/cpp/_nv_utils_8h_source.html
# TensorRT-7.0.0.11/doc/cpp/annotated.html
# TensorRT-7.0.0.11/doc/cpp/annotated_dup.js
# TensorRT-7.0.0.11/doc/cpp/bc_s.png
# TensorRT-7.0.0.11/doc/cpp/bdwn.png
# TensorRT-7.0.0.11/doc/cpp/classes.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_binary_proto_blob-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_binary_proto_blob.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_binary_proto_blob.js
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_blob_name_to_tensor-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_blob_name_to_tensor.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_blob_name_to_tensor.js
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_caffe_parser-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_caffe_parser.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_caffe_parser.js
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory.js
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory.png
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory_ext-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory_ext.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory_ext.js
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory_ext.png
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory_v2-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory_v2.html
# TensorRT-7.0.0.11/doc/cpp/classnvcaffeparser1_1_1_i_plugin_factory_v2.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims2-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims2.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims2.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims2.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims3-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims3.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims3.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims3.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims4-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims4.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims4.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims4.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_c_h_w-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_c_h_w.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_c_h_w.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_c_h_w.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_exprs-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_exprs.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_exprs.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_h_w-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_h_w.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_h_w.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_h_w.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_n_c_h_w-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_n_c_h_w.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_n_c_h_w.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_dims_n_c_h_w.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_activation_layer-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_activation_layer.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_activation_layer.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_activation_layer.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_layer.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_builder-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_builder.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_builder.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_builder_config-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_builder_config.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_builder_config.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_concatenation_layer-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_concatenation_layer.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_concatenation_layer.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_concatenation_layer.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_constant_layer-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_constant_layer.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_constant_layer.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_constant_layer.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_convolution_layer-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_convolution_layer.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_convolution_layer.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_convolution_layer.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_cuda_engine-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_cuda_engine.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_cuda_engine.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_deconvolution_layer-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_deconvolution_layer.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_deconvolution_layer.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_deconvolution_layer.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_dimension_expr-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_dimension_expr.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_dimension_expr.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_element_wise_layer-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_element_wise_layer.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_element_wise_layer.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_element_wise_layer.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_error_recorder-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_error_recorder.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_error_recorder.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_execution_context-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_execution_context.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_execution_context.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_expr_builder-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_expr_builder.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_expr_builder.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_fill_layer-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_fill_layer.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_fill_layer.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_fill_layer.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_fully_connected_layer-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_fully_connected_layer.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_fully_connected_layer.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_fully_connected_layer.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_gather_layer-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_gather_layer.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_gather_layer.js
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_gather_layer.png
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_gpu_allocator-members.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_gpu_allocator.html
# TensorRT-7.0.0.11/doc/cpp/classnvinfer1_1_1_i_gpu_allocator.js
# ...
# TensorRT-7.0.0.11/doc/cpp/functions_p.html
# TensorRT-7.0.0.11/doc/cpp/functions_r.html
# TensorRT-7.0.0.11/doc/cpp/functions_s.html
# TensorRT-7.0.0.11/doc/cpp/functions_t.html
# TensorRT-7.0.0.11/doc/cpp/functions_type.html
# TensorRT-7.0.0.11/doc/cpp/functions_u.html
# TensorRT-7.0.0.11/doc/cpp/functions_v.html
# TensorRT-7.0.0.11/doc/cpp/functions_vars.html
# TensorRT-7.0.0.11/doc/cpp/functions_w.html
# TensorRT-7.0.0.11/doc/cpp/globals.html
# TensorRT-7.0.0.11/doc/cpp/globals_defs.html
# TensorRT-7.0.0.11/doc/cpp/globals_func.html
# TensorRT-7.0.0.11/doc/cpp/globals_type.html
# TensorRT-7.0.0.11/doc/cpp/hierarchy.html
# TensorRT-7.0.0.11/doc/cpp/hierarchy.js
# TensorRT-7.0.0.11/doc/cpp/index.html
# TensorRT-7.0.0.11/doc/cpp/jquery.js
# TensorRT-7.0.0.11/doc/cpp/menu.js
# TensorRT-7.0.0.11/doc/cpp/menudata.js
# TensorRT-7.0.0.11/doc/cpp/namespacemembers.html
# TensorRT-7.0.0.11/doc/cpp/namespacemembers_enum.html
# TensorRT-7.0.0.11/doc/cpp/namespacemembers_func.html
# TensorRT-7.0.0.11/doc/cpp/namespacemembers_type.html
# TensorRT-7.0.0.11/doc/cpp/namespacenvcaffeparser1.html
# TensorRT-7.0.0.11/doc/cpp/namespacenvcaffeparser1.js
# TensorRT-7.0.0.11/doc/cpp/namespacenvinfer1.html
# TensorRT-7.0.0.11/doc/cpp/namespacenvinfer1.js
# TensorRT-7.0.0.11/doc/cpp/namespacenvinfer1_1_1anonymous__namespace_02_nv_infer_8h_03.html
# TensorRT-7.0.0.11/doc/cpp/namespacenvinfer1_1_1anonymous__namespace_02_nv_infer_runtime_8h_03.html
# TensorRT-7.0.0.11/doc/cpp/namespacenvuffparser.html
# TensorRT-7.0.0.11/doc/cpp/namespacenvuffparser.js
# TensorRT-7.0.0.11/doc/cpp/namespaces.html
# TensorRT-7.0.0.11/doc/cpp/namespaces.js
# TensorRT-7.0.0.11/doc/cpp/nav_f.png
# TensorRT-7.0.0.11/doc/cpp/nav_g.png
# TensorRT-7.0.0.11/doc/cpp/nav_h.png
# TensorRT-7.0.0.11/doc/cpp/navtree.css
# TensorRT-7.0.0.11/doc/cpp/navtree.js
# TensorRT-7.0.0.11/doc/cpp/navtreedata.js
# TensorRT-7.0.0.11/doc/cpp/navtreeindex0.js
# TensorRT-7.0.0.11/doc/cpp/navtreeindex1.js
# TensorRT-7.0.0.11/doc/cpp/navtreeindex2.js
# TensorRT-7.0.0.11/doc/cpp/navtreeindex3.js
# TensorRT-7.0.0.11/doc/cpp/navtreeindex4.js
# TensorRT-7.0.0.11/doc/cpp/navtreeindex5.js
# TensorRT-7.0.0.11/doc/cpp/open.png
# TensorRT-7.0.0.11/doc/cpp/pages.html
# TensorRT-7.0.0.11/doc/cpp/resize.js
# TensorRT-7.0.0.11/doc/cpp/search/
# TensorRT-7.0.0.11/doc/cpp/search/search_l.png
# TensorRT-7.0.0.11/doc/cpp/search/search_m.png
# TensorRT-7.0.0.11/doc/cpp/search/search_r.png
# TensorRT-7.0.0.11/doc/cpp/search/close.png
# TensorRT-7.0.0.11/doc/cpp/search/mag_sel.png
# TensorRT-7.0.0.11/doc/cpp/search/search.css
# TensorRT-7.0.0.11/doc/cpp/search/all_0.html
# TensorRT-7.0.0.11/doc/cpp/search/all_0.js
# TensorRT-7.0.0.11/doc/cpp/search/all_1.html
# TensorRT-7.0.0.11/doc/cpp/search/all_1.js
# TensorRT-7.0.0.11/doc/cpp/search/all_2.html
# TensorRT-7.0.0.11/doc/cpp/search/all_2.js
# TensorRT-7.0.0.11/doc/cpp/search/all_3.html
# TensorRT-7.0.0.11/doc/cpp/search/all_3.js
# TensorRT-7.0.0.11/doc/cpp/search/all_4.html
# TensorRT-7.0.0.11/doc/cpp/search/all_4.js
# TensorRT-7.0.0.11/doc/cpp/search/all_5.html
# TensorRT-7.0.0.11/doc/cpp/search/all_5.js
# TensorRT-7.0.0.11/doc/cpp/search/all_6.html
# TensorRT-7.0.0.11/doc/cpp/search/all_6.js
# TensorRT-7.0.0.11/doc/cpp/search/all_7.html
# TensorRT-7.0.0.11/doc/cpp/search/all_7.js
# TensorRT-7.0.0.11/doc/cpp/search/all_8.html
# TensorRT-7.0.0.11/doc/cpp/search/all_8.js
# TensorRT-7.0.0.11/doc/cpp/search/all_9.html
# TensorRT-7.0.0.11/doc/cpp/search/all_9.js
# TensorRT-7.0.0.11/doc/cpp/search/all_a.html
# TensorRT-7.0.0.11/doc/cpp/search/all_a.js
# TensorRT-7.0.0.11/doc/cpp/search/all_b.html
# TensorRT-7.0.0.11/doc/cpp/search/all_b.js
# TensorRT-7.0.0.11/doc/cpp/search/all_c.html
# TensorRT-7.0.0.11/doc/cpp/search/all_c.js
# TensorRT-7.0.0.11/doc/cpp/search/all_d.html
# TensorRT-7.0.0.11/doc/cpp/search/all_d.js
# TensorRT-7.0.0.11/doc/cpp/search/all_e.html
# TensorRT-7.0.0.11/doc/cpp/search/all_e.js
# TensorRT-7.0.0.11/doc/cpp/search/all_f.html
# TensorRT-7.0.0.11/doc/cpp/search/all_f.js
# TensorRT-7.0.0.11/doc/cpp/search/all_10.html
# TensorRT-7.0.0.11/doc/cpp/search/all_10.js
# TensorRT-7.0.0.11/doc/cpp/search/all_11.html
# TensorRT-7.0.0.11/doc/cpp/search/all_11.js
# TensorRT-7.0.0.11/doc/cpp/search/all_12.html
# TensorRT-7.0.0.11/doc/cpp/search/all_12.js
# TensorRT-7.0.0.11/doc/cpp/search/all_13.html
# TensorRT-7.0.0.11/doc/cpp/search/all_13.js
# TensorRT-7.0.0.11/doc/cpp/search/all_14.html
# TensorRT-7.0.0.11/doc/cpp/search/all_14.js
# TensorRT-7.0.0.11/doc/cpp/search/all_15.html
# TensorRT-7.0.0.11/doc/cpp/search/all_15.js
# TensorRT-7.0.0.11/doc/cpp/search/all_16.html
# TensorRT-7.0.0.11/doc/cpp/search/all_16.js
# TensorRT-7.0.0.11/doc/cpp/search/all_17.html
# TensorRT-7.0.0.11/doc/cpp/search/all_17.js
# TensorRT-7.0.0.11/doc/cpp/search/classes_0.html
# TensorRT-7.0.0.11/doc/cpp/search/classes_0.js
# TensorRT-7.0.0.11/doc/cpp/search/classes_1.html
# TensorRT-7.0.0.11/doc/cpp/search/classes_1.js
# TensorRT-7.0.0.11/doc/cpp/search/classes_2.html
# TensorRT-7.0.0.11/doc/cpp/search/classes_2.js
# TensorRT-7.0.0.11/doc/cpp/search/classes_3.html
# TensorRT-7.0.0.11/doc/cpp/search/classes_3.js
# TensorRT-7.0.0.11/doc/cpp/search/classes_4.html
# TensorRT-7.0.0.11/doc/cpp/search/classes_4.js
# TensorRT-7.0.0.11/doc/cpp/search/classes_5.html
# TensorRT-7.0.0.11/doc/cpp/search/classes_5.js
# TensorRT-7.0.0.11/doc/cpp/search/classes_6.html
# TensorRT-7.0.0.11/doc/cpp/search/classes_6.js
# TensorRT-7.0.0.11/doc/cpp/search/classes_7.html
# TensorRT-7.0.0.11/doc/cpp/search/classes_7.js
# TensorRT-7.0.0.11/doc/cpp/search/classes_8.html
# TensorRT-7.0.0.11/doc/cpp/search/classes_8.js
# TensorRT-7.0.0.11/doc/cpp/search/classes_9.html
# TensorRT-7.0.0.11/doc/cpp/search/classes_9.js
# TensorRT-7.0.0.11/doc/cpp/search/namespaces_0.html
# TensorRT-7.0.0.11/doc/cpp/search/namespaces_0.js
# TensorRT-7.0.0.11/doc/cpp/search/files_0.html
# TensorRT-7.0.0.11/doc/cpp/search/files_0.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_0.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_0.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_1.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_1.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_2.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_2.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_3.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_3.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_4.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_4.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_5.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_5.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_6.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_6.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_7.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_7.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_8.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_8.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_9.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_9.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_a.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_a.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_b.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_b.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_c.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_c.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_d.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_d.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_e.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_e.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_f.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_f.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_10.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_10.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_11.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_11.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_12.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_12.js
# TensorRT-7.0.0.11/doc/cpp/search/functions_13.html
# TensorRT-7.0.0.11/doc/cpp/search/functions_13.js
# TensorRT-7.0.0.11/doc/cpp/search/variables_0.html
# TensorRT-7.0.0.11/doc/cpp/search/variables_0.js
# TensorRT-7.0.0.11/doc/cpp/search/variables_1.html
# TensorRT-7.0.0.11/doc/cpp/search/variables_1.js
# TensorRT-7.0.0.11/doc/cpp/search/variables_2.html
# TensorRT-7.0.0.11/doc/cpp/search/variables_2.js
# TensorRT-7.0.0.11/doc/cpp/search/variables_3.html
# TensorRT-7.0.0.11/doc/cpp/search/variables_3.js
# TensorRT-7.0.0.11/doc/cpp/search/variables_4.html
# TensorRT-7.0.0.11/doc/cpp/search/variables_4.js
# TensorRT-7.0.0.11/doc/cpp/search/variables_5.html
# TensorRT-7.0.0.11/doc/cpp/search/variables_5.js
# TensorRT-7.0.0.11/doc/cpp/search/variables_6.html
# TensorRT-7.0.0.11/doc/cpp/search/variables_6.js
# TensorRT-7.0.0.11/doc/cpp/search/variables_7.html
# TensorRT-7.0.0.11/doc/cpp/search/variables_7.js
# TensorRT-7.0.0.11/doc/cpp/search/variables_8.html
# TensorRT-7.0.0.11/doc/cpp/search/variables_8.js
# TensorRT-7.0.0.11/doc/cpp/search/variables_9.html
# TensorRT-7.0.0.11/doc/cpp/search/variables_9.js
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_0.html
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_0.js
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_1.html
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_1.js
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_2.html
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_2.js
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_3.html
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_3.js
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_4.html
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_4.js
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_5.html
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_5.js
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_6.html
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_6.js
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_7.html
# TensorRT-7.0.0.11/doc/cpp/search/typedefs_7.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_0.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_0.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_1.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_1.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_2.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_2.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_3.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_3.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_4.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_4.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_5.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_5.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_6.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_6.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_7.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_7.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_8.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_8.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_9.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_9.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_a.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_a.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_b.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_b.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_c.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_c.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_d.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_d.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_e.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_e.js
# TensorRT-7.0.0.11/doc/cpp/search/enums_f.html
# TensorRT-7.0.0.11/doc/cpp/search/enums_f.js
# TensorRT-7.0.0.11/doc/cpp/search/enumvalues_0.html
# TensorRT-7.0.0.11/doc/cpp/search/enumvalues_0.js
# TensorRT-7.0.0.11/doc/cpp/search/defines_0.html
# TensorRT-7.0.0.11/doc/cpp/search/defines_0.js
# TensorRT-7.0.0.11/doc/cpp/search/defines_1.html
# TensorRT-7.0.0.11/doc/cpp/search/defines_1.js
# TensorRT-7.0.0.11/doc/cpp/search/pages_0.html
# TensorRT-7.0.0.11/doc/cpp/search/pages_0.js
# TensorRT-7.0.0.11/doc/cpp/search/searchdata.js
# TensorRT-7.0.0.11/doc/cpp/search/search.js
# TensorRT-7.0.0.11/doc/cpp/search/nomatches.html
# TensorRT-7.0.0.11/doc/cpp/splitbar.png
# TensorRT-7.0.0.11/doc/cpp/struct_plugin_version.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_dynamic_plugin_tensor_desc-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_dynamic_plugin_tensor_desc.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_dynamic_plugin_tensor_desc.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_permutation-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_permutation.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_permutation.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_plugin_field-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_plugin_field.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_plugin_field.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_plugin_field_collection-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_plugin_field_collection.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_plugin_field_collection.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_plugin_tensor_desc-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_plugin_tensor_desc.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1_plugin_tensor_desc.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_detection_output_parameters-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_detection_output_parameters.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_detection_output_parameters.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_grid_anchor_parameters-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_grid_anchor_parameters.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_grid_anchor_parameters.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_n_m_s_parameters-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_n_m_s_parameters.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_n_m_s_parameters.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_prior_box_parameters-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_prior_box_parameters.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_prior_box_parameters.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_quadruple-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_quadruple.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_quadruple.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_r_p_r_o_i_params-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_r_p_r_o_i_params.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_r_p_r_o_i_params.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_region_parameters-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_region_parameters.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1_region_parameters.js
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1softmax_tree-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1softmax_tree.html
# TensorRT-7.0.0.11/doc/cpp/structnvinfer1_1_1plugin_1_1softmax_tree.js
# TensorRT-7.0.0.11/doc/cpp/structnvuffparser_1_1_field_collection-members.html
# TensorRT-7.0.0.11/doc/cpp/structnvuffparser_1_1_field_collection.html
# TensorRT-7.0.0.11/doc/cpp/structnvuffparser_1_1_field_collection.js
# TensorRT-7.0.0.11/doc/cpp/sync_off.png
# TensorRT-7.0.0.11/doc/cpp/sync_on.png
# TensorRT-7.0.0.11/doc/cpp/tab_a.png
# TensorRT-7.0.0.11/doc/cpp/tab_b.png
# TensorRT-7.0.0.11/doc/cpp/tab_h.png
# TensorRT-7.0.0.11/doc/cpp/tab_s.png
# TensorRT-7.0.0.11/doc/cpp/tabs.css
# TensorRT-7.0.0.11/doc/Acknowledgements.txt
# TensorRT-7.0.0.11/doc/pdf/
# TensorRT-7.0.0.11/doc/pdf/TensorRT-Best-Practices.pdf
# TensorRT-7.0.0.11/doc/pdf/TensorRT-Developer-Guide.pdf
# TensorRT-7.0.0.11/doc/pdf/TensorRT-Installation-Guide.pdf
# TensorRT-7.0.0.11/doc/pdf/TensorRT-Release-Notes.pdf
# TensorRT-7.0.0.11/doc/pdf/TensorRT-SLA.pdf
# TensorRT-7.0.0.11/doc/pdf/TensorRT-Sample-Support-Guide.pdf
# TensorRT-7.0.0.11/doc/pdf/TensorRT-Support-Matrix-Guide.pdf
# TensorRT-7.0.0.11/TensorRT-Release-Notes.pdf
# TensorRT-7.0.0.11/python/
# TensorRT-7.0.0.11/python/tensorrt-7.0.0.11-cp27-none-linux_x86_64.whl
# TensorRT-7.0.0.11/python/tensorrt-7.0.0.11-cp34-none-linux_x86_64.whl
# TensorRT-7.0.0.11/python/tensorrt-7.0.0.11-cp35-none-linux_x86_64.whl
# TensorRT-7.0.0.11/python/tensorrt-7.0.0.11-cp36-none-linux_x86_64.whl
# TensorRT-7.0.0.11/python/tensorrt-7.0.0.11-cp37-none-linux_x86_64.whl
# TensorRT-7.0.0.11/uff/
# TensorRT-7.0.0.11/uff/uff-0.6.5-py2.py3-none-any.whl
# TensorRT-7.0.0.11/graphsurgeon/
# TensorRT-7.0.0.11/graphsurgeon/graphsurgeon-0.4.1-py2.py3-none-any.whl

# %% [markdown]
# # Build necessary plugin library

# %%
# !python TensorRT-7.0.0.11/samples/python/uff_ssd/detect_objects.py TensorRT-7.0.0.11/samples/python/uff_ssd/images/image2.jpg
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/graphsurgeon/_utils.py:2: The name tf.NodeDef is deprecated. Please use tf.compat.v1.NodeDef instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/graphsurgeon/DynamicGraph.py:4: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# Preparing pretrained model
# Downloading /content/gdrive/My Drive/Colab Notebooks/TensorRT Colab Test/TensorRT-7.0.0.11/samples/python/uff_ssd/utils/../workspace/models/ssd_inception_v2_coco_2017_11_17.tar.gz
# Download progress [==================================================] 100.00%
# Download complete
# Unpacking /content/gdrive/My Drive/Colab Notebooks/TensorRT Colab Test/TensorRT-7.0.0.11/samples/python/uff_ssd/utils/../workspace/models/ssd_inception_v2_coco_2017_11_17.tar.gz
# Extracting complete
# Removing /content/gdrive/My Drive/Colab Notebooks/TensorRT Colab Test/TensorRT-7.0.0.11/samples/python/uff_ssd/utils/../workspace/models/ssd_inception_v2_coco_2017_11_17.tar.gz
# Model ready
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/graphsurgeon/StaticGraph.py:125: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING: To create TensorRT plugin nodes, please use the `create_plugin_node` function instead.
# UFF Version 0.6.5
# === Automatically deduced input nodes ===
# [name: "Input"
# op: "Placeholder"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 300
#       }
#       dim {
#         size: 300
#       }
#     }
#   }
# }
# ]
# =========================================
#
# Using output node NMS
# Converting to UFF graph
# Warning: No conversion function registered for layer: NMS_TRT yet.
# Converting NMS as custom op: NMS_TRT
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/uff/converters/tensorflow/converter.py:179: The name tf.AttrValue is deprecated. Please use tf.compat.v1.AttrValue instead.
#
# Warning: No conversion function registered for layer: FlattenConcat_TRT yet.
# Converting concat_box_conf as custom op: FlattenConcat_TRT
# Warning: No conversion function registered for layer: GridAnchor_TRT yet.
# Converting GridAnchor as custom op: GridAnchor_TRT
# Warning: No conversion function registered for layer: FlattenConcat_TRT yet.
# Converting concat_box_loc as custom op: FlattenConcat_TRT
# DEBUG [/usr/local/lib/python3.6/dist-packages/uff/converters/tensorflow/converter.py:96] Marking ['NMS'] as outputs
# No. nodes: 563
# UFF Output written to /content/gdrive/My Drive/Colab Notebooks/TensorRT Colab Test/TensorRT-7.0.0.11/samples/python/uff_ssd/utils/../workspace/models/ssd_inception_v2_coco_2017_11_17/frozen_inference_graph.uff
# UFF Text Output written to /content/gdrive/My Drive/Colab Notebooks/TensorRT Colab Test/TensorRT-7.0.0.11/samples/python/uff_ssd/utils/../workspace/models/ssd_inception_v2_coco_2017_11_17/frozen_inference_graph.pbtxt
# TensorRT inference engine settings:
#   * Inference precision - DataType.FLOAT
#   * Max batch size - 1
#
# Building TensorRT engine. This may take few minutes.
# [TensorRT] WARNING: TensorRT was linked against cuDNN 7.6.3 but loaded cuDNN 7.6.2
# [TensorRT] WARNING: TensorRT was linked against cuDNN 7.6.3 but loaded cuDNN 7.6.2
# [TensorRT] WARNING: TensorRT was linked against cuDNN 7.6.3 but loaded cuDNN 7.6.2
# [TensorRT] WARNING: Current optimization profile is: 0. Please ensure there are no enqueued operations pending in this context prior to switching profiles
# TensorRT inference time: 11 ms
# Detected kite with confidence 97%
# Detected person with confidence 91%
# Detected kite with confidence 89%
# Detected person with confidence 89%
# Detected kite with confidence 83%
# Detected kite with confidence 82%
# Detected person with confidence 76%
# Detected kite with confidence 74%
# Detected person with confidence 70%
# Detected person with confidence 62%
# Detected person with confidence 59%
# Total time taken for one image: 153 ms
#
# Saved output image to: /content/gdrive/My Drive/Colab Notebooks/TensorRT Colab Test/TensorRT-7.0.0.11/samples/python/uff_ssd/utils/../image_inferred.jpg

# %%
# !ls
# Out:
#  cuda-repo-ubuntu1804_10.0.130-1_amd64.deb
#  graphsurgeon-0.4.1-py2.py3-none-any.whl
#  nvidia-machine-learning-repo-ubuntu1804_1.0.0-1_amd64.deb
#  nv-tensorrt-repo-ubuntu1804-cuda10.0-trt7.0.0.11-ga-20191216_1-1_amd64.deb
#  tensorrt-7.0.0.11-cp36-none-linux_x86_64.whl
#  TensorRT-7.0.0.11.Ubuntu-18.04.x86_64-gnu.cuda-10.0.cudnn7.6.tar.gz
# 'tensorrt colab test.ipynb'
#  uff-0.6.5-py2.py3-none-any.whl
